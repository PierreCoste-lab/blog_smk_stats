# %% [markdown]
# ## 06 - MIN, MAX and MEAN STATS

# %% [markdown]
# <img src="photo_02.jpg">
# [Source: FFSMK](http://www.ffsmk.org/images/photos/smkchamp2019/ECAIYzVWwAAzMy3.jpg)

# %% [markdown]
# #### Library imports

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# #### Load File

# %%
df = pd.read_csv('smk_stats_v10.csv', sep = ';', encoding = 'iso-8859-1')

# %% [markdown]
# #### Data Preparation

# %% [markdown]
# #### 1) Data preparation for global distribution

# %%
# TRANSFORMATION DES COLONNES 2 à 24 en Datetime pour pouvoir prendre en compte les chronos.
df['MC1'] = pd.to_datetime(df['MC1'], format='%M:%S,%f')
df['DP1'] = pd.to_datetime(df['DP1'], format='%M:%S,%f')
df['GV1'] = pd.to_datetime(df['GV1'], format='%M:%S,%f')
df['BC1'] = pd.to_datetime(df['BC1'], format='%M:%S,%f')
df['MC2'] = pd.to_datetime(df['MC2'], format='%M:%S,%f')
df['CI1'] = pd.to_datetime(df['CI1'], format='%M:%S,%f')
df['GV2'] = pd.to_datetime(df['GV2'], format='%M:%S,%f')
df['DP2'] = pd.to_datetime(df['DP2'], format='%M:%S,%f')
df['BC2'] = pd.to_datetime(df['BC2'], format='%M:%S,%f')
df['MC3'] = pd.to_datetime(df['MC3'], format='%M:%S,%f')
df['KB1'] = pd.to_datetime(df['KB1'], format='%M:%S,%f')
df['CI2'] = pd.to_datetime(df['CI2'], format='%M:%S,%f')
df['VL1'] = pd.to_datetime(df['VL1'], format='%M:%S,%f')
df['BC3'] = pd.to_datetime(df['BC3'], format='%M:%S,%f')
df['MC4'] = pd.to_datetime(df['MC4'], format='%M:%S,%f')
df['DP3'] = pd.to_datetime(df['DP3'], format='%M:%S,%f')
df['KB2'] = pd.to_datetime(df['KB2'], format='%M:%S,%f')
df['GV3'] = pd.to_datetime(df['GV3'], format='%M:%S,%f')
df['VL2'] = pd.to_datetime(df['VL2'], format='%M:%S,%f')
df['RR'] = pd.to_datetime(df['RR'], format='%M:%S,%f')
df['Total Time'] = pd.to_datetime(df['Total Time'], format='%M:%S,%f')

# %%
# Clean toutes les données égales à 1900-01-01 00:09:59.990  et instanciation de variables pour chacun des circuits:
mc1_all = df[df['MC1'] != '1900-01-01 00:09:59.990']
dp1_all = df[df['DP1'] != '1900-01-01 00:09:59.990']
gv1_all = df[df['GV1'] != '1900-01-01 00:09:59.990']
bc1_all = df[df['BC1'] != '1900-01-01 00:09:59.990']
mc2_all = df[df['MC2'] != '1900-01-01 00:09:59.990']
ci1_all = df[df['CI1'] != '1900-01-01 00:09:59.990']
gv2_all = df[df['GV2'] != '1900-01-01 00:09:59.990']
dp2_all = df[df['DP2'] != '1900-01-01 00:09:59.990']
bc2_all = df[df['BC2'] != '1900-01-01 00:09:59.990']
mc3_all = df[df['MC3'] != '1900-01-01 00:09:59.990']
kb1_all = df[df['KB1'] != '1900-01-01 00:09:59.990']
ci2_all = df[df['CI2'] != '1900-01-01 00:09:59.990']
vl1_all = df[df['VL1'] != '1900-01-01 00:09:59.990']
bc3_all = df[df['BC3'] != '1900-01-01 00:09:59.990']
mc4_all = df[df['MC4'] != '1900-01-01 00:09:59.990']
dp3_all = df[df['DP3'] != '1900-01-01 00:09:59.990']
kb2_all = df[df['KB2'] != '1900-01-01 00:09:59.990']
gv3_all = df[df['GV3'] != '1900-01-01 00:09:59.990']
vl2_all = df[df['VL2'] != '1900-01-01 00:09:59.990']
rr_all = df[df['RR'] != '1900-01-01 00:09:59.990']

# %%
# Instanciation des min, max, et mean sous forme de string
mc1_min_string = str(mc1_all['MC1'].min())
mc1_max_string = str(mc1_all['MC1'].max())
mc1_mean_string = str(mc1_all['MC1'].mean())
dp1_min_string = str(dp1_all['DP1'].min())
dp1_max_string = str(dp1_all['DP1'].max())
dp1_mean_string = str(dp1_all['DP1'].mean())
gv1_min_string = str(gv1_all['GV1'].min())
gv1_max_string = str(gv1_all['GV1'].max())
gv1_mean_string = str(dp1_all['GV1'].mean())
bc1_min_string = str(bc1_all['BC1'].min())
bc1_max_string = str(bc1_all['BC1'].max())
bc1_mean_string = str(bc1_all['BC1'].mean())
mc2_min_string = str(mc2_all['MC2'].min())
mc2_max_string = str(mc2_all['MC2'].max())
mc2_mean_string = str(mc2_all['MC2'].mean())
ci1_min_string = str(ci1_all['CI1'].min())
ci1_max_string = str(ci1_all['CI1'].max())
ci1_mean_string = str(ci1_all['CI1'].mean())
gv2_min_string = str(gv2_all['GV2'].min())
gv2_max_string = str(gv2_all['GV2'].max())
gv2_mean_string = str(gv2_all['GV2'].mean())
dp2_min_string = str(dp2_all['DP2'].min())
dp2_max_string = str(dp2_all['DP2'].max())
dp2_mean_string = str(dp2_all['DP2'].mean())
bc2_min_string = str(bc2_all['BC2'].min())
bc2_max_string = str(bc2_all['BC2'].max())
bc2_mean_string = str(bc2_all['BC2'].mean())
mc3_min_string = str(mc3_all['MC3'].min())
mc3_max_string = str(mc3_all['MC3'].max())
mc3_mean_string = str(mc3_all['MC3'].mean())
kb1_min_string = str(kb1_all['KB1'].min())
kb1_max_string = str(kb1_all['KB1'].max())
kb1_mean_string = str(kb1_all['KB1'].mean())
ci2_min_string = str(ci2_all['CI2'].min())
ci2_max_string = str(ci2_all['CI2'].max())
ci2_mean_string = str(ci2_all['CI2'].mean())
vl1_min_string = str(vl1_all['VL1'].min())
vl1_max_string = str(vl1_all['VL1'].max())
vl1_mean_string = str(vl1_all['VL1'].mean())
bc3_min_string = str(bc3_all['BC3'].min())
bc3_max_string = str(bc3_all['BC3'].max())
bc3_mean_string = str(bc3_all['BC3'].mean())
mc4_min_string = str(mc4_all['MC4'].min())
mc4_max_string = str(mc4_all['MC4'].max())
mc4_mean_string = str(mc4_all['MC4'].mean())
dp3_min_string = str(dp3_all['DP3'].min())
dp3_max_string = str(dp3_all['DP3'].max())
dp3_mean_string = str(dp3_all['DP3'].mean())
kb2_min_string = str(kb2_all['KB2'].min())
kb2_max_string = str(kb2_all['KB2'].max())
kb2_mean_string = str(kb2_all['KB2'].mean())
gv3_min_string = str(gv3_all['GV3'].min())
gv3_max_string = str(gv3_all['GV3'].max())
gv3_mean_string = str(gv3_all['GV3'].mean())
vl2_min_string = str(vl2_all['VL2'].min())
vl2_max_string = str(vl2_all['VL2'].max())
vl2_mean_string = str(vl2_all['VL2'].mean())
rr_min_string = str(rr_all['RR'].min())
rr_max_string = str(rr_all['RR'].max())
rr_mean_string = str(rr_all['RR'].mean())

# %%
# Récupérer les valeurs des chronos sous forme de string pour chaque circuit
mc1_min = mc1_min_string[14:-4]
mc1_max = mc1_max_string[14:-4]
mc1_mean = mc1_mean_string[14:-7]
dp1_min = dp1_min_string[14:-4]
dp1_max = dp1_max_string[14:-4]
dp1_mean= dp1_mean_string[14:-7]
gv1_min = gv1_min_string[14:-4]
gv1_max = gv1_max_string[14:-4]
gv1_mean = gv1_mean_string[14:-7]
bc1_min = bc1_min_string[14:-4]
bc1_max = bc1_max_string[14:-4]
bc1_mean = bc1_mean_string[14:-7]
mc2_min = mc2_min_string[14:-4]
mc2_max = mc2_max_string[14:-4]
mc2_mean = mc2_mean_string[14:-7]
ci1_min = ci1_min_string[14:-4]
ci1_max = ci1_max_string[14:-4]
ci1_mean = ci1_mean_string[14:-7]
gv2_min = gv2_min_string[14:-4]
gv2_max = gv2_max_string[14:-4]
gv2_mean = gv2_mean_string[14:-7]
dp2_min = dp2_min_string[14:-4]
dp2_max = dp2_max_string[14:-4]
dp2_mean = dp2_mean_string[14:-7]
bc2_min = bc2_min_string[14:-4]
bc2_max = bc2_max_string[14:-4]
bc2_mean = bc2_mean_string[14:-7]
mc3_min = mc3_min_string[14:-4]
mc3_max = mc3_max_string[14:-4]
mc3_mean = mc3_mean_string[14:-7]
kb1_min = kb1_min_string[14:-4]
kb1_max = kb1_max_string[14:-4]
kb1_mean = kb1_mean_string[14:-7]
ci2_min = ci2_min_string[14:-4]
ci2_max = ci2_max_string[14:-4]
ci2_mean = ci2_mean_string[14:-7]
vl1_min = vl1_min_string[14:-4]
vl1_max = vl1_max_string[14:-4]
vl1_mean = vl1_mean_string[14:-7]
bc3_min = bc3_min_string[14:-4]
bc3_max = bc3_max_string[14:-4]
bc3_mean = bc3_mean_string[14:-7]
mc4_min = mc4_min_string[14:-4]
mc4_max = mc4_max_string[14:-4]
mc4_mean = mc4_mean_string[14:-7]
dp3_min = dp3_min_string[14:-4]
dp3_max = dp3_max_string[14:-4]
dp3_mean = dp3_mean_string[14:-7]
kb2_min = kb2_min_string[14:-4]
kb2_max = kb2_max_string[14:-4]
kb2_mean = kb2_mean_string[14:-7]
gv3_min = gv3_min_string[14:-4]
gv3_max = gv3_max_string[14:-4]
gv3_mean = gv3_mean_string[14:-7]
vl2_min = vl2_min_string[14:-4]
vl2_max = vl2_max_string[14:-4]
vl2_mean= vl2_mean_string[14:-7]
rr_min = rr_min_string[14:-4]
rr_max = rr_max_string[14:-4]
rr_mean = rr_mean_string[14:-7]

# %%
print(f'Best One-Try done at Mario Circuit 1 in World Championships between 2012 and 2019: "{mc1_min}".')
print(f'Worst One-Try done at Mario Circuit 1 in World Championships between 2012 and 2019: "{mc1_max}".')
print(f'Mean of all Mario Circuit 1 times in World Championships between 2012 and 2019: "{mc1_mean}".\n')

print(f'Best One-Try done at Donut Plains 1 in World Championships between 2012 and 2019: "{dp1_min}".')
print(f'Worst One-Try done at Donut Plains 1 in World Championships between 2012 and 2019: "{dp1_max}".')
print(f'Mean of all Donut Plains 1 times in World Championships between 2012 and 2019: "{dp1_mean}".\n')

print(f'Best One-Try done at Ghost Valley 1 in World Championships between 2012 and 2019: "{gv1_min}".')
print(f'Worst One-Try done at Ghost Valley 1 in World Championships between 2012 and 2019: "{gv1_max}".')
print(f'Mean of all Ghost Valley 1 times in World Championships between 2012 and 2019: "{gv1_mean}".\n')

print(f'Best One-Try done at Bowser Castle 1 in World Championships between 2012 and 2019: "{bc1_min}".')
print(f'Worst One-Try done at Bowser Castle 1 in World Championships between 2012 and 2019: "{bc1_max}".')
print(f'Mean of all Bowser Castle 1 times in World Championships between 2012 and 2019: "{bc1_mean}".\n')

print(f'Best One-Try done at Mario Circuit 2 in World Championships between 2012 and 2019: "{mc2_min}".')
print(f'Worst One-Try done at Mario Circuit 2 in World Championships between 2012 and 2019: "{mc2_max}".')
print(f'Mean of all Mario Circuit 2 times in World Championships between 2012 and 2019: "{mc2_mean}".\n')

print(f'Best One-Try done at Choco Island 1 in World Championships between 2012 and 2019: "{ci1_min}".')
print(f'Worst One-Try done at Choco Island 1 in World Championships between 2012 and 2019: "{ci1_max}".')
print(f'Mean of all Choco Island 1 times in World Championships between 2012 and 2019: "{ci1_mean}".\n')

print(f'Best One-Try done at Ghost Valley 2 in World Championships between 2012 and 2019: "{gv2_min}".')
print(f'Worst One-Try done at Ghost Valley 2 in World Championships between 2012 and 2019: "{gv2_max}".')
print(f'Mean of all Ghost Valley 2 times in World Championships between 2012 and 2019: "{gv2_mean}".\n')

print(f'Best One-Try done at Donut plains 2 in World Championships between 2012 and 2019: "{dp2_min}".')
print(f'Worst One-Try done at Donut plains 2 in World Championships between 2012 and 2019: "{dp2_max}".')
print(f'Mean of all Donut plains 2 times in World Championships between 2012 and 2019: "{dp2_mean}".\n')

print(f'Best One-Try done at Bowser Castle 2 in World Championships between 2012 and 2019: "{bc2_min}".')
print(f'Worst One-Try done at Bowser Castle 2 in World Championships between 2012 and 2019: "{bc2_max}".')
print(f'Mean of all Bowser Castle 2 times in World Championships between 2012 and 2019: "{bc2_mean}".\n')

print(f'Best One-Try done at Mario Circuit 3 in World Championships between 2012 and 2019: "{mc3_min}".')
print(f'Worst One-Try done at Mario Circuit 3 in World Championships between 2012 and 2019: "{mc3_max}".')
print(f'Mean of all Mario Circuit 3 times in World Championships between 2012 and 2019: "{mc3_mean}".\n')

print(f'Best One-Try done at Koopa Beach 1 in World Championships between 2012 and 2019: "{kb1_min}".')
print(f'Worst One-Try done at Koopa Beach 1  in World Championships between 2012 and 2019: "{kb1_max}".')
print(f'Mean of all Koopa Beach 1 times in World Championships between 2012 and 2019: "{kb1_mean}".\n')

print(f'Best One-Try done at Choco Island 2 in World Championships between 2012 and 2019: "{ci2_min}".')
print(f'Worst One-Try done at Choco Island 2 in World Championships between 2012 and 2019: "{ci2_max}".')
print(f'Mean of all Choco Island 2 times in World Championships between 2012 and 2019: "{ci2_mean}".\n')

print(f'Best One-Try done at Vanilla Lake 1 in World Championships between 2012 and 2019: "{vl1_min}".')
print(f'Worst One-Try done at Vanilla Lake 1 in World Championships between 2012 and 2019: "{vl1_max}".')
print(f'Mean of all Vanilla Lake 1 times in World Championships between 2012 and 2019: "{vl1_mean}".\n')

print(f'Best One-Try done at Bowser Castle 3 in World Championships between 2012 and 2019: "{bc3_min}".')
print(f'Worst One-Try done at Bowser Castle 3 in World Championships between 2012 and 2019: "{bc3_max}".')
print(f'Mean of all Bowser Castle 3  times in World Championships between 2012 and 2019: "{bc3_mean}".\n')

print(f'Best One-Try done at Mario Circuit 4 in World Championships between 2012 and 2019: "{mc4_min}".')
print(f'Worst One-Try done at Mario Circuit 4 in World Championships between 2012 and 2019: "{mc4_max}".')
print(f'Mean of all Mario Circuit 4 times in World Championships between 2012 and 2019: "{mc4_mean}".\n')

print(f'Best One-Try done at Donut plains 3 in World Championships between 2012 and 2019: "{dp3_min}".')
print(f'Worst One-Try done at Donut plains 3  in World Championships between 2012 and 2019: "{dp3_max}".')
print(f'Mean of all Donut plains 3 times in World Championships between 2012 and 2019: "{dp3_mean}".\n')

print(f'Best One-Try done at Koopa Beach 2 in World Championships between 2012 and 2019: "{kb2_min}".')
print(f'Worst One-Try done at Koopa Beach 2  in World Championships between 2012 and 2019: "{kb2_max}".')
print(f'Mean of all Koopa Beach 2  times in World Championships between 2012 and 2019: "{kb2_mean}".\n')

print(f'Best One-Try done at Ghost Valley 3 in World Championships between 2012 and 2019: "{gv3_min}".')
print(f'Worst One-Try done at Ghost Valley 3 in World Championships between 2012 and 2019: "{gv3_max}".')
print(f'Mean of all Ghost Valley 3 times in World Championships between 2012 and 2019: "{gv3_mean}".\n')

print(f'Best One-Try done at Vanilla Lake 2 in World Championships between 2012 and 2019: "{vl2_min}".')
print(f'Worst One-Try done at Vanilla Lake 2 in World Championships between 2012 and 2019: "{vl2_max}".')
print(f'Mean of all Vanilla Lake 2 times in World Championships between 2012 and 2019: "{vl2_mean}".\n')

print(f'Best One-Try done at Rainbow Road in World Championships between 2012 and 2019: "{rr_min}".')
print(f'Worst One-Try done at Rainbow Road in World Championships between 2012 and 2019: "{rr_max}".')
print(f'Mean of all Rainbow Road times in World Championships between 2012 and 2019: "{rr_mean}".\n')
# Out:
# Best One-Try done at Mario Circuit 1 in World Championships between 2012 and 2019: "00:58.96".
# Worst One-Try done at Mario Circuit 1 in World Championships between 2012 and 2019: "01:30.36".
# Mean of all Mario Circuit 1 times in World Championships between 2012 and 2019: "01:05.23".
#
# Best One-Try done at Donut Plains 1 in World Championships between 2012 and 2019: "01:11.34".
# Worst One-Try done at Donut Plains 1 in World Championships between 2012 and 2019: "02:05.05".
# Mean of all Donut Plains 1 times in World Championships between 2012 and 2019: "01:23.67".
#
# Best One-Try done at Ghost Valley 1 in World Championships between 2012 and 2019: "01:06.54".
# Worst One-Try done at Ghost Valley 1 in World Championships between 2012 and 2019: "02:08.61".
# Mean of all Ghost Valley 1 times in World Championships between 2012 and 2019: "01:36.15".
#
# Best One-Try done at Bowser Castle 1 in World Championships between 2012 and 2019: "01:28.83".
# ...

# %% [markdown]
# #### 2) Data preparation for Top 16 groupe stage distribution

# %%
# Identifier les membres du top 16 et les instancier -> Colonnes Phase ou Position peuvent nous aider
top_16_global = df[(df['Phase'] == 'Group Stage') & (df['Position'] < 17)]

# %%
# Instanciation des min, max, et mean sous forme de string
mc1_min_top16_string = str(top_16_global['MC1'].min())
mc1_max_top16_string = str(top_16_global['MC1'].max())
mc1_mean_top16_string = str(top_16_global['MC1'].mean())
dp1_min_top16_string = str(top_16_global['DP1'].min())
dp1_max_top16_string = str(top_16_global['DP1'].max())
dp1_mean_top16_string = str(top_16_global['DP1'].mean())
gv1_min_top16_string = str(top_16_global['GV1'].min())
gv1_max_top16_string = str(top_16_global['GV1'].max())
gv1_mean_top16_string = str(top_16_global['GV1'].mean())
bc1_min_top16_string = str(top_16_global['BC1'].min())
bc1_max_top16_string = str(top_16_global['BC1'].max())
bc1_mean_top16_string = str(top_16_global['BC1'].mean())
mc2_min_top16_string = str(top_16_global['MC2'].min())
mc2_max_top16_string = str(top_16_global['MC2'].max())
mc2_mean_top16_string = str(top_16_global['MC2'].mean())
ci1_min_top16_string = str(top_16_global['CI1'].min())
ci1_max_top16_string = str(top_16_global['CI1'].max())
ci1_mean_top16_string = str(top_16_global['CI1'].mean())
gv2_min_top16_string = str(top_16_global['GV2'].min())
gv2_max_top16_string = str(top_16_global['GV2'].max())
gv2_mean_top16_string = str(top_16_global['GV2'].mean())
dp2_min_top16_string = str(top_16_global['DP2'].min())
dp2_max_top16_string = str(top_16_global['DP2'].max())
dp2_mean_top16_string = str(top_16_global['DP2'].mean())
bc2_min_top16_string = str(top_16_global['BC2'].min())
bc2_max_top16_string = str(top_16_global['BC2'].max())
bc2_mean_top16_string = str(top_16_global['BC2'].mean())
mc3_min_top16_string = str(top_16_global['MC3'].min())
mc3_max_top16_string = str(top_16_global['MC3'].max())
mc3_mean_top16_string = str(top_16_global['MC3'].mean())
kb1_min_top16_string = str(top_16_global['KB1'].min())
kb1_max_top16_string = str(top_16_global['KB1'].max())
kb1_mean_top16_string = str(top_16_global['KB1'].mean())
ci2_min_top16_string = str(top_16_global['CI2'].min())
ci2_max_top16_string = str(top_16_global['CI2'].max())
ci2_mean_top16_string = str(top_16_global['CI2'].mean())
vl1_min_top16_string = str(top_16_global['VL1'].min())
vl1_max_top16_string = str(top_16_global['VL1'].max())
vl1_mean_top16_string = str(top_16_global['VL1'].mean())
bc3_min_top16_string = str(top_16_global['BC3'].min())
bc3_max_top16_string = str(top_16_global['BC3'].max())
bc3_mean_top16_string = str(top_16_global['BC3'].mean())
mc4_min_top16_string = str(top_16_global['MC4'].min())
mc4_max_top16_string = str(top_16_global['MC4'].max())
mc4_mean_top16_string = str(top_16_global['MC4'].mean())
dp3_min_top16_string = str(top_16_global['DP3'].min())
dp3_max_top16_string = str(top_16_global['DP3'].max())
dp3_mean_top16_string = str(top_16_global['DP3'].mean())
kb2_min_top16_string = str(top_16_global['KB2'].min())
kb2_max_top16_string = str(top_16_global['KB2'].max())
kb2_mean_top16_string = str(top_16_global['KB2'].mean())
gv3_min_top16_string = str(top_16_global['GV3'].min())
gv3_max_top16_string = str(top_16_global['GV3'].max())
gv3_mean_top16_string = str(top_16_global['GV3'].mean())
vl2_min_top16_string = str(top_16_global['VL2'].min())
vl2_max_top16_string = str(top_16_global['VL2'].max())
vl2_mean_top16_string = str(top_16_global['VL2'].mean())
rr_min_top16_string = str(top_16_global['RR'].min())
rr_max_top16_string = str(top_16_global['RR'].max())
rr_mean_top16_string = str(top_16_global['RR'].mean())

# %%
# Récupérer les valeurs des chronos sous forme de string pour chaque circuit
mc1_min_top16 = mc1_min_top16_string[14:-4]
mc1_max_top16 = mc1_max_top16_string[14:-4]
mc1_mean_top16 = mc1_mean_top16_string[14:-7]
dp1_min_top16 = dp1_min_top16_string[14:-4]
dp1_max_top16 = dp1_max_top16_string[14:-4]
dp1_mean_top16 = dp1_mean_top16_string[14:-7]
gv1_min_top16 = gv1_min_top16_string[14:-4]
gv1_max_top16 = gv1_max_top16_string[14:-4]
gv1_mean_top16 = gv1_mean_top16_string[14:-7]
bc1_min_top16 = bc1_min_top16_string[14:-4]
bc1_max_top16 = bc1_max_top16_string[14:-4]
bc1_mean_top16 = bc1_mean_top16_string[14:-7]
mc2_min_top16 = mc2_min_top16_string[14:-4]
mc2_max_top16 = mc2_max_top16_string[14:-4]
mc2_mean_top16 = mc2_mean_top16_string[14:-7]
ci1_min_top16 = ci1_min_top16_string[14:-4]
ci1_max_top16 = ci1_max_top16_string[14:-4]
ci1_mean_top16 = ci1_mean_top16_string[14:-7]
gv2_min_top16 = gv2_min_top16_string[14:-4]
gv2_max_top16 = gv2_max_top16_string[14:-4]
gv2_mean_top16 = gv2_mean_top16_string[14:-7]
dp2_min_top16 = dp2_min_top16_string[14:-4]
dp2_max_top16 = dp2_max_top16_string[14:-4]
dp2_mean_top16 = dp2_mean_top16_string[14:-7]
bc2_min_top16 = bc2_min_top16_string[14:-4]
bc2_max_top16 = bc2_max_top16_string[14:-4]
bc2_mean_top16 = bc2_mean_top16_string[14:-7]
mc3_min_top16 = mc3_min_top16_string[14:-4]
mc3_max_top16 = mc3_max_top16_string[14:-4]
mc3_mean_top16 = mc3_mean_top16_string[14:-7]
kb1_min_top16 = kb1_min_top16_string[14:-4]
kb1_max_top16 = kb1_max_top16_string[14:-4]
kb1_mean_top16 = kb1_mean_top16_string[14:-7]
ci2_min_top16 = ci2_min_top16_string[14:-4]
ci2_max_top16 = ci2_max_top16_string[14:-4]
ci2_mean_top16 = ci2_mean_top16_string[14:-7]
vl1_min_top16 = vl1_min_top16_string[14:-4]
vl1_max_top16 = vl1_max_top16_string[14:-4]
vl1_mean_top16 = vl1_mean_top16_string[14:-7]
bc3_min_top16 = bc3_min_top16_string[14:-4]
bc3_max_top16 = bc3_max_top16_string[14:-4]
bc3_mean_top16 = bc3_mean_top16_string[14:-7]
mc4_min_top16 = mc4_min_top16_string[14:-4]
mc4_max_top16 = mc4_max_top16_string[14:-4]
mc4_mean_top16 = mc4_mean_top16_string[14:-7]
dp3_min_top16 = dp3_min_top16_string[14:-4]
dp3_max_top16 = dp3_max_top16_string[14:-4]
dp3_mean_top16 = dp3_mean_top16_string[14:-7]
kb2_min_top16 = kb2_min_top16_string[14:-4]
kb2_max_top16 = kb2_max_top16_string[14:-4]
kb2_mean_top16 = kb2_mean_top16_string[14:-7]
gv3_min_top16 = gv3_min_top16_string[14:-4]
gv3_max_top16 = gv3_max_top16_string[14:-4]
gv3_mean_top16 = gv3_mean_top16_string[14:-7]
vl2_min_top16 = vl2_min_top16_string[14:-4]
vl2_max_top16 = vl2_max_top16_string[14:-4]
vl2_mean_top16 = vl2_mean_top16_string[14:-7]
rr_min_top16 = rr_min_top16_string[14:-4]
rr_max_top16 = rr_max_top16_string[14:-4]
rr_mean_top16 = rr_mean_top16_string[14:-7]

# %%
print(f'Best One-Try done at Mario Circuit 1 in World Championships for Top 16 Group Stage members: "{mc1_min_top16}".')
print(f'Worst One-Try done at Mario Circuit 1 in World Championships for Top 16 Group Stage members: "{mc1_max_top16}".')
print(f'Mean of Mario Circuit 1 times in World Championships for Top 16 Group Stage members: "{mc1_mean_top16}".\n')

print(f'Best One-Try done at Donut Plains 1 in World Championships for Top 16 Group Stage members: "{dp1_min_top16}".')
print(f'Worst One-Try done at Donut Plains 1 in World Championships for Top 16 Group Stage members: "{dp1_max_top16}".')
print(f'Mean of Donut Plains 1 times in World Championships for Top 16 Group Stage members: "{dp1_mean_top16}".\n')

print(f'Best One-Try done at Ghost Valley 1 in World Championships for Top 16 Group Stage members: "{gv1_min_top16}".')
print(f'Worst One-Try done at Ghost Valley 1 in World Championships for Top 16 Group Stage members: "{gv1_max_top16}".')
print(f'Mean of Ghost Valley 1 times in World Championships for Top 16 Group Stage members: "{gv1_mean_top16}".\n')

print(f'Best One-Try done at Bowser Castle 1 in World Championships for Top 16 Group Stage members: "{bc1_min_top16}".')
print(f'Worst One-Try done at Bowser Castle 1 in World Championships for Top 16 Group Stage members: "{bc1_max_top16}".')
print(f'Mean of Bowser Castle 1 times in World Championships for Top 16 Group Stage members: "{bc1_mean_top16}".\n')

print(f'Best One-Try done at Mario Circuit 2 in World Championships for Top 16 Group Stage members: "{mc2_min_top16}".')
print(f'Worst One-Try done at Mario Circuit 2 in World Championships for Top 16 Group Stage members: "{mc2_max_top16}".')
print(f'Mean of Mario Circuit 2 times in World Championships for Top 16 Group Stage members: "{mc2_mean_top16}".\n')

print(f'Best One-Try done at Choco Island 1 in World Championships for Top 16 Group Stage members: "{ci1_min_top16}".')
print(f'Worst One-Try done at Choco Island 1 in World Championships for Top 16 Group Stage members: "{ci1_max_top16}".')
print(f'Mean of Choco Island 1 times in World Championships for Top 16 Group Stage members: "{ci1_mean_top16}".\n')

print(f'Best One-Try done at Ghost Valley 2 in World Championships for Top 16 Group Stage members: "{gv2_min_top16}".')
print(f'Worst One-Try done at Ghost Valley 2 in World Championships for Top 16 Group Stage members: "{gv2_max_top16}".')
print(f'Mean of Ghost Valley 2 times in World Championships for Top 16 Group Stage members: "{gv2_mean_top16}".\n')

print(f'Best One-Try done at Donut plains 2 in World Championships for Top 16 Group Stage members: "{dp2_min_top16}".')
print(f'Worst One-Try done at Donut plains 2 in World Championships for Top 16 Group Stage members: "{dp2_max_top16}".')
print(f'Mean of Donut plains 2 times in World Championships for Top 16 Group Stage members: "{dp2_mean_top16}".\n')

print(f'Best One-Try done at Bowser Castle 2 in World Championships for Top 16 Group Stage members: "{bc2_min_top16}".')
print(f'Worst One-Try done at Bowser Castle 2 in World Championships for Top 16 Group Stage members: "{bc2_max_top16}".')
print(f'Mean of Bowser Castle 2 times in World Championships for Top 16 Group Stage members: "{bc2_mean_top16}".\n')

print(f'Best One-Try done at Mario Circuit 3 in World Championships for Top 16 Group Stage members: "{mc3_min_top16}".')
print(f'Worst One-Try done at Mario Circuit 3 in World Championships for Top 16 Group Stage members: "{mc3_max_top16}".')
print(f'Mean of Mario Circuit 3 times in World Championships for Top 16 Group Stage members: "{mc3_mean_top16}".\n')

print(f'Best One-Try done at Koopa Beach 1 in World Championships for Top 16 Group Stage members: "{kb1_min_top16}".')
print(f'Worst One-Try done at Koopa Beach 1  in World Championships for Top 16 Group Stage members: "{kb1_max_top16}".')
print(f'Mean of Koopa Beach 1 times in World Championships for Top 16 Group Stage members: "{kb1_mean_top16}".\n')

print(f'Best One-Try done at Choco Island 2 in World Championships for Top 16 Group Stage members: "{ci2_min_top16}".')
print(f'Worst One-Try done at Choco Island 2 in World Championships for Top 16 Group Stage members: "{ci2_max_top16}".')
print(f'Mean of Choco Island 2 times in World Championships for Top 16 Group Stage members: "{ci2_mean_top16}".\n')

print(f'Best One-Try done at Vanilla Lake 1 in World Championships for Top 16 Group Stage members: "{vl1_min_top16}".')
print(f'Worst One-Try done at Vanilla Lake 1 in World Championships for Top 16 Group Stage members: "{vl1_max_top16}".')
print(f'Mean of Vanilla Lake 1 times in World Championships for Top 16 Group Stage members: "{vl1_mean_top16}".\n')

print(f'Best One-Try done at Bowser Castle 3 in World Championships for Top 16 Group Stage members: "{bc3_min_top16}".')
print(f'Worst One-Try done at Bowser Castle 3 in World Championships for Top 16 Group Stage members: "{bc3_max_top16}".')
print(f'Mean of Bowser Castle 3  times in World Championships for Top 16 Group Stage members: "{bc3_mean_top16}".\n')

print(f'Best One-Try done at Mario Circuit 4 in World Championships for Top 16 Group Stage members: "{mc4_min_top16}".')
print(f'Worst One-Try done at Mario Circuit 4 in World Championships for Top 16 Group Stage members: "{mc4_max_top16}".')
print(f'Mean of Mario Circuit 4 times in World Championships for Top 16 Group Stage members: "{mc4_mean_top16}".\n')

print(f'Best One-Try done at Donut plains 3 in World Championships for Top 16 Group Stage members: "{dp3_min_top16}".')
print(f'Worst One-Try done at Donut plains 3  in World Championships for Top 16 Group Stage members: "{dp3_max_top16}".')
print(f'Mean of Donut plains 3 times in World Championships for Top 16 Group Stage members: "{dp3_mean_top16}".\n')

print(f'Best One-Try done at Koopa Beach 2 in World Championships for Top 16 Group Stage members: "{kb2_min_top16}".')
print(f'Worst One-Try done at Koopa Beach 2  in World Championships for Top 16 Group Stage members: "{kb2_max_top16}".')
print(f'Mean of Koopa Beach 2  times in World Championships for Top 16 Group Stage members: "{kb2_mean_top16}".\n')

print(f'Best One-Try done at Ghost Valley 3 in World Championships for Top 16 Group Stage members: "{gv3_min_top16}".')
print(f'Worst One-Try done at Ghost Valley 3 in World Championships for Top 16 Group Stage members: "{gv3_max_top16}".')
print(f'Mean of Ghost Valley 3 times in World Championships for Top 16 Group Stage members: "{gv3_mean_top16}".\n')

print(f'Best One-Try done at Vanilla Lake 2 in World Championships for Top 16 Group Stage members: "{vl2_min_top16}".')
print(f'Worst One-Try done at Vanilla Lake 2 in World Championships for Top 16 Group Stage members: "{vl2_max_top16}".')
print(f'Mean of Vanilla Lake 2 times in World Championships for Top 16 Group Stage members: "{vl2_mean_top16}".\n')

print(f'Best One-Try done at Rainbow Road in World Championships for Top 16 Group Stage members: "{rr_min_top16}".')
print(f'Worst One-Try done at Rainbow Road in World Championships for Top 16 Group Stage members: "{rr_max_top16}".')
print(f'Mean of Rainbow Road times in World Championships for Top 16 Group Stage members: "{rr_mean_top16}".\n')
# Out:
# Best One-Try done at Mario Circuit 1 in World Championships for Top 16 Group Stage members: "00:58.96".
# Worst One-Try done at Mario Circuit 1 in World Championships for Top 16 Group Stage members: "01:06.50".
# Mean of Mario Circuit 1 times in World Championships for Top 16 Group Stage members: "01:01.66".
#
# Best One-Try done at Donut Plains 1 in World Championships for Top 16 Group Stage members: "01:11.34".
# Worst One-Try done at Donut Plains 1 in World Championships for Top 16 Group Stage members: "01:25.51".
# Mean of Donut Plains 1 times in World Championships for Top 16 Group Stage members: "01:16.28".
#
# Best One-Try done at Ghost Valley 1 in World Championships for Top 16 Group Stage members: "01:06.54".
# Worst One-Try done at Ghost Valley 1 in World Championships for Top 16 Group Stage members: "01:17.41".
# Mean of Ghost Valley 1 times in World Championships for Top 16 Group Stage members: "01:08.90".
#
# ...

# %% [markdown]
# #### 3) Data preparation for Top 8 groupe stage distribution

# %%
# Identifier et instancier de manière globale le Top 8 en Groupe Stage sur l'ensemble des années
top8_group_stage = df[(df['Phase'] == 'Group Stage') & (df['Position'] < 9)]

# %%
# Instanciation des min, max, et mean sous forme de string
mc1_min_top8_string = str(top8_group_stage['MC1'].min())
mc1_max_top8_string = str(top8_group_stage['MC1'].max())
mc1_mean_top8_string = str(top8_group_stage['MC1'].mean())
dp1_min_top8_string = str(top8_group_stage['DP1'].min())
dp1_max_top8_string = str(top8_group_stage['DP1'].max())
dp1_mean_top8_string = str(top8_group_stage['DP1'].mean())
gv1_min_top8_string = str(top8_group_stage['GV1'].min())
gv1_max_top8_string = str(top8_group_stage['GV1'].max())
gv1_mean_top8_string = str(top8_group_stage['GV1'].mean())
bc1_min_top8_string = str(top8_group_stage['BC1'].min())
bc1_max_top8_string = str(top8_group_stage['BC1'].max())
bc1_mean_top8_string = str(top8_group_stage['BC1'].mean())
mc2_min_top8_string = str(top8_group_stage['MC2'].min())
mc2_max_top8_string = str(top8_group_stage['MC2'].max())
mc2_mean_top8_string = str(top8_group_stage['MC2'].mean())
ci1_min_top8_string = str(top8_group_stage['CI1'].min())
ci1_max_top8_string = str(top8_group_stage['CI1'].max())
ci1_mean_top8_string = str(top8_group_stage['CI1'].mean())
gv2_min_top8_string = str(top8_group_stage['GV2'].min())
gv2_max_top8_string = str(top8_group_stage['GV2'].max())
gv2_mean_top8_string = str(top8_group_stage['GV2'].mean())
dp2_min_top8_string = str(top8_group_stage['DP2'].min())
dp2_max_top8_string = str(top8_group_stage['DP2'].max())
dp2_mean_top8_string = str(top8_group_stage['DP2'].mean())
bc2_min_top8_string = str(top8_group_stage['BC2'].min())
bc2_max_top8_string = str(top8_group_stage['BC2'].max())
bc2_mean_top8_string = str(top8_group_stage['BC2'].mean())
mc3_min_top8_string = str(top8_group_stage['MC3'].min())
mc3_max_top8_string = str(top8_group_stage['MC3'].max())
mc3_mean_top8_string = str(top8_group_stage['MC3'].mean())
kb1_min_top8_string = str(top8_group_stage['KB1'].min())
kb1_max_top8_string = str(top8_group_stage['KB1'].max())
kb1_mean_top8_string = str(top8_group_stage['KB1'].mean())
ci2_min_top8_string = str(top8_group_stage['CI2'].min())
ci2_max_top8_string = str(top8_group_stage['CI2'].max())
ci2_mean_top8_string = str(top8_group_stage['CI2'].mean())
vl1_min_top8_string = str(top8_group_stage['VL1'].min())
vl1_max_top8_string = str(top8_group_stage['VL1'].max())
vl1_mean_top8_string = str(top8_group_stage['VL1'].mean())
bc3_min_top8_string = str(top8_group_stage['BC3'].min())
bc3_max_top8_string = str(top8_group_stage['BC3'].max())
bc3_mean_top8_string = str(top8_group_stage['BC3'].mean())
mc4_min_top8_string = str(top8_group_stage['MC4'].min())
mc4_max_top8_string = str(top8_group_stage['MC4'].max())
mc4_mean_top8_string = str(top8_group_stage['MC4'].mean())
dp3_min_top8_string = str(top8_group_stage['DP3'].min())
dp3_max_top8_string = str(top8_group_stage['DP3'].max())
dp3_mean_top8_string = str(top8_group_stage['DP3'].mean())
kb2_min_top8_string = str(top8_group_stage['KB2'].min())
kb2_max_top8_string = str(top8_group_stage['KB2'].max())
kb2_mean_top8_string = str(top8_group_stage['KB2'].mean())
gv3_min_top8_string = str(top8_group_stage['GV3'].min())
gv3_max_top8_string = str(top8_group_stage['GV3'].max())
gv3_mean_top8_string = str(top8_group_stage['GV3'].mean())
vl2_min_top8_string = str(top8_group_stage['VL2'].min())
vl2_max_top8_string = str(top8_group_stage['VL2'].max())
vl2_mean_top8_string = str(top8_group_stage['VL2'].mean())
rr_min_top8_string = str(top8_group_stage['RR'].min())
rr_max_top8_string = str(top8_group_stage['RR'].max())
rr_mean_top8_string = str(top8_group_stage['RR'].mean())

# %%
# Récupérer les valeurs des chronos sous forme de string pour chaque circuit
mc1_min_top8 = mc1_min_top8_string[14:-4]
mc1_max_top8 = mc1_max_top8_string[14:-4]
mc1_mean_top8 = mc1_mean_top8_string[14:-7]
dp1_min_top8 = dp1_min_top8_string[14:-4]
dp1_max_top8 = dp1_max_top8_string[14:-4]
dp1_mean_top8 = dp1_mean_top8_string[14:-7]
gv1_min_top8 = gv1_min_top8_string[14:-4]
gv1_max_top8 = gv1_max_top8_string[14:-4]
gv1_mean_top8 = gv1_mean_top8_string[14:-7]
bc1_min_top8 = bc1_min_top8_string[14:-4]
bc1_max_top8 = bc1_max_top8_string[14:-4]
bc1_mean_top8 = bc1_mean_top8_string[14:-7]
mc2_min_top8 = mc2_min_top8_string[14:-4]
mc2_max_top8 = mc2_max_top8_string[14:-4]
mc2_mean_top8 = mc2_mean_top8_string[14:-7]
ci1_min_top8 = ci1_min_top8_string[14:-4]
ci1_max_top8 = ci1_max_top8_string[14:-4]
ci1_mean_top8 = ci1_mean_top8_string[14:-7]
gv2_min_top8 = gv2_min_top8_string[14:-4]
gv2_max_top8 = gv2_max_top8_string[14:-4]
gv2_mean_top8 = gv2_mean_top8_string[14:-7]
dp2_min_top8 = dp2_min_top8_string[14:-4]
dp2_max_top8 = dp2_max_top8_string[14:-4]
dp2_mean_top8 = dp2_mean_top8_string[14:-7]
bc2_min_top8 = bc2_min_top8_string[14:-4]
bc2_max_top8 = bc2_max_top8_string[14:-4]
bc2_mean_top8 = bc2_mean_top8_string[14:-7]
mc3_min_top8 = mc3_min_top8_string[14:-4]
mc3_max_top8 = mc3_max_top8_string[14:-4]
mc3_mean_top8 = mc3_mean_top8_string[14:-7]
kb1_min_top8 = kb1_min_top8_string[14:-4]
kb1_max_top8 = kb1_max_top8_string[14:-4]
kb1_mean_top8 = kb1_mean_top8_string[14:-7]
ci2_min_top8 = ci2_min_top8_string[14:-4]
ci2_max_top8 = ci2_max_top8_string[14:-4]
ci2_mean_top8 = ci2_mean_top8_string[14:-7]
vl1_min_top8 = vl1_min_top8_string[14:-4]
vl1_max_top8 = vl1_max_top8_string[14:-4]
vl1_mean_top8 = vl1_mean_top8_string[14:-7]
bc3_min_top8 = bc3_min_top8_string[14:-4]
bc3_max_top8 = bc3_max_top8_string[14:-4]
bc3_mean_top8 = bc3_mean_top8_string[14:-7]
mc4_min_top8 = mc4_min_top8_string[14:-4]
mc4_max_top8 = mc4_max_top8_string[14:-4]
mc4_mean_top8 = mc4_mean_top8_string[14:-7]
dp3_min_top8 = dp3_min_top8_string[14:-4]
dp3_max_top8 = dp3_max_top8_string[14:-4]
dp3_mean_top8 = dp3_mean_top8_string[14:-7]
kb2_min_top8 = kb2_min_top8_string[14:-4]
kb2_max_top8 = kb2_max_top8_string[14:-4]
kb2_mean_top8 = kb2_mean_top8_string[14:-7]
gv3_min_top8 = gv3_min_top8_string[14:-4]
gv3_max_top8 = gv3_max_top8_string[14:-4]
gv3_mean_top8 = gv3_mean_top8_string[14:-7]
vl2_min_top8 = vl2_min_top8_string[14:-4]
vl2_max_top8 = vl2_max_top8_string[14:-4]
vl2_mean_top8 = vl2_mean_top8_string[14:-7]
rr_min_top8 = rr_min_top8_string[14:-4]
rr_max_top8 = rr_max_top8_string[14:-4]
rr_mean_top8 = rr_mean_top8_string[14:-7]

# %%
print(f'Best One-Try done at Mario Circuit 1 in World Championships for Top 8 Group Stage members: "{mc1_min_top8}".')
print(f'Worst One-Try done at Mario Circuit 1 in World Championships for Top 8 Group Stage members: "{mc1_max_top8}".')
print(f'Mean of Mario Circuit 1 times in World Championships for Top 8 Group Stage members: "{mc1_mean_top8}".\n')

print(f'Best One-Try done at Donut Plains 1 in World Championships for Top 8 Group Stage members: "{dp1_min_top8}".')
print(f'Worst One-Try done at Donut Plains 1 in World Championships for Top 8 Group Stage members: "{dp1_max_top8}".')
print(f'Mean of Donut Plains 1 times in World Championships for Top 8 Group Stage members: "{dp1_mean_top8}".\n')

print(f'Best One-Try done at Ghost Valley 1 in World Championships for Top 8 Group Stage members: "{gv1_min_top8}".')
print(f'Worst One-Try done at Ghost Valley 1 in World Championships for Top 8 Group Stage members: "{gv1_max_top8}".')
print(f'Mean of Ghost Valley 1 times in World Championships for Top 8 Group Stage members: "{gv1_mean_top8}".\n')

print(f'Best One-Try done at Bowser Castle 1 in World Championships for Top 8 Group Stage members: "{bc1_min_top8}".')
print(f'Worst One-Try done at Bowser Castle 1 in World Championships for Top 8 Group Stage members: "{bc1_max_top8}".')
print(f'Mean of Bowser Castle 1 times in World Championships for Top 8 Group Stage members: "{bc1_mean_top8}".\n')

print(f'Best One-Try done at Mario Circuit 2 in World Championships for Top 8 Group Stage members: "{mc2_min_top8}".')
print(f'Worst One-Try done at Mario Circuit 2 in World Championships for Top 8 Group Stage members: "{mc2_max_top8}".')
print(f'Mean of Mario Circuit 2 times in World Championships for Top 8 Group Stage members: "{mc2_mean_top8}".\n')

print(f'Best One-Try done at Choco Island 1 in World Championships for Top 8 Group Stage members: "{ci1_min_top8}".')
print(f'Worst One-Try done at Choco Island 1 in World Championships for Top 8 Group Stage members: "{ci1_max_top8}".')
print(f'Mean of Choco Island 1 times in World Championships for Top 8 Group Stage members: "{ci1_mean_top8}".\n')

print(f'Best One-Try done at Ghost Valley 2 in World Championships for Top 8 Group Stage members: "{gv2_min_top8}".')
print(f'Worst One-Try done at Ghost Valley 2 in World Championships for Top 8 Group Stage members: "{gv2_max_top8}".')
print(f'Mean of Ghost Valley 2 times in World Championships for Top 8 Group Stage members: "{gv2_mean_top8}".\n')

print(f'Best One-Try done at Donut plains 2 in World Championships for Top 8 Group Stage members: "{dp2_min_top8}".')
print(f'Worst One-Try done at Donut plains 2 in World Championships for Top 8 Group Stage members: "{dp2_max_top8}".')
print(f'Mean of Donut plains 2 times in World Championships for Top 8 Group Stage members: "{dp2_mean_top8}".\n')

print(f'Best One-Try done at Bowser Castle 2 in World Championships for Top 8 Group Stage members: "{bc2_min_top8}".')
print(f'Worst One-Try done at Bowser Castle 2 in World Championships for Top 8 Group Stage members: "{bc2_max_top8}".')
print(f'Mean of Bowser Castle 2 times in World Championships for Top 8 Group Stage members: "{bc2_mean_top8}".\n')

print(f'Best One-Try done at Mario Circuit 3 in World Championships for Top 8 Group Stage members: "{mc3_min_top8}".')
print(f'Worst One-Try done at Mario Circuit 3 in World Championships for Top 8 Group Stage members: "{mc3_max_top8}".')
print(f'Mean of Mario Circuit 3 times in World Championships for Top 8 Group Stage members: "{mc3_mean_top8}".\n')

print(f'Best One-Try done at Koopa Beach 1 in World Championships for Top 8 Group Stage members: "{kb1_min_top8}".')
print(f'Worst One-Try done at Koopa Beach 1  in World Championships for Top 8 Group Stage members: "{kb1_max_top8}".')
print(f'Mean of Koopa Beach 1 times in World Championships for Top 8 Group Stage members: "{kb1_mean_top8}".\n')

print(f'Best One-Try done at Choco Island 2 in World Championships for Top 8 Group Stage members: "{ci2_min_top8}".')
print(f'Worst One-Try done at Choco Island 2 in World Championships for Top 8 Group Stage members: "{ci2_max_top8}".')
print(f'Mean of Choco Island 2 times in World Championships for Top 8 Group Stage members: "{ci2_mean_top8}".\n')

print(f'Best One-Try done at Vanilla Lake 1 in World Championships for Top 8 Group Stage members: "{vl1_min_top8}".')
print(f'Worst One-Try done at Vanilla Lake 1 in World Championships for Top 8 Group Stage members: "{vl1_max_top8}".')
print(f'Mean of Vanilla Lake 1 times in World Championships for Top 8 Group Stage members: "{vl1_mean_top8}".\n')

print(f'Best One-Try done at Bowser Castle 3 in World Championships for Top 8 Group Stage members: "{bc3_min_top8}".')
print(f'Worst One-Try done at Bowser Castle 3 in World Championships for Top 8 Group Stage members: "{bc3_max_top8}".')
print(f'Mean of Bowser Castle 3  times in World Championships for Top 8 Group Stage members: "{bc3_mean_top8}".\n')

print(f'Best One-Try done at Mario Circuit 4 in World Championships for Top 8 Group Stage members: "{mc4_min_top8}".')
print(f'Worst One-Try done at Mario Circuit 4 in World Championships for Top 8 Group Stage members: "{mc4_max_top8}".')
print(f'Mean of Mario Circuit 4 times in World Championships for Top 8 Group Stage members: "{mc4_mean_top8}".\n')

print(f'Best One-Try done at Donut plains 3 in World Championships for Top 8 Group Stage members: "{dp3_min_top8}".')
print(f'Worst One-Try done at Donut plains 3  in World Championships for Top 8 Group Stage members: "{dp3_max_top8}".')
print(f'Mean of Donut plains 3 times in World Championships for Top 8 Group Stage members: "{dp3_mean_top8}".\n')

print(f'Best One-Try done at Koopa Beach 2 in World Championships for Top 8 Group Stage members: "{kb2_min_top8}".')
print(f'Worst One-Try done at Koopa Beach 2  in World Championships for Top 8 Group Stage members: "{kb2_max_top8}".')
print(f'Mean of Koopa Beach 2  times in World Championships for Top 8 Group Stage members: "{kb2_mean_top8}".\n')

print(f'Best One-Try done at Ghost Valley 3 in World Championships for Top 8 Group Stage members: "{gv3_min_top8}".')
print(f'Worst One-Try done at Ghost Valley 3 in World Championships for Top 8 Group Stage members: "{gv3_max_top8}".')
print(f'Mean of Ghost Valley 3 times in World Championships for Top 8 Group Stage members: "{gv3_mean_top8}".\n')

print(f'Best One-Try done at Vanilla Lake 2 in World Championships for Top 8 Group Stage members: "{vl2_min_top8}".')
print(f'Worst One-Try done at Vanilla Lake 2 in World Championships for Top 8 Group Stage members: "{vl2_max_top8}".')
print(f'Mean of Vanilla Lake 2 times in World Championships for Top 8 Group Stage members: "{vl2_mean_top8}".\n')

print(f'Best One-Try done at Rainbow Road in World Championships for Top 8 Group Stage members: "{rr_min_top8}".')
print(f'Worst One-Try done at Rainbow Road in World Championships for Top 8 Group Stage members: "{rr_max_top8}".')
print(f'Mean of Rainbow Road times in World Championships for Top 8 Group Stage members: "{rr_mean_top8}".\n')
# Out:
# Best One-Try done at Mario Circuit 1 in World Championships for Top 8 Group Stage members: "00:58.96".
# Worst One-Try done at Mario Circuit 1 in World Championships for Top 8 Group Stage members: "01:05.68".
# Mean of Mario Circuit 1 times in World Championships for Top 8 Group Stage members: "01:00.63".
#
# Best One-Try done at Donut Plains 1 in World Championships for Top 8 Group Stage members: "01:11.34".
# Worst One-Try done at Donut Plains 1 in World Championships for Top 8 Group Stage members: "01:18.96".
# Mean of Donut Plains 1 times in World Championships for Top 8 Group Stage members: "01:14.45".
#
# Best One-Try done at Ghost Valley 1 in World Championships for Top 8 Group Stage members: "01:06.54".
# Worst One-Try done at Ghost Valley 1 in World Championships for Top 8 Group Stage members: "01:13.59".
# Mean of Ghost Valley 1 times in World Championships for Top 8 Group Stage members: "01:08.43".
#
# ...

# %% [markdown]
# #### 2) Data preparation for Final Phase Distribution

# %%
# Identifier tous les temps effectués en Phase Finale de 2012 à 2019.
# Il va falloir instancier une variable par course sinon les lignes en 09:59,99 seront supprimées
final_phase_global_mc1 = df[(df['Phase'] != 'Group Stage') & (df['MC1'] != '1900-01-01 00:09:59.990')]
final_phase_global_dp1 = df[(df['Phase'] != 'Group Stage') & (df['DP1'] != '1900-01-01 00:09:59.990')]
final_phase_global_gv1 = df[(df['Phase'] != 'Group Stage') & (df['GV1'] != '1900-01-01 00:09:59.990')]
final_phase_global_bc1 = df[(df['Phase'] != 'Group Stage') & (df['BC1'] != '1900-01-01 00:09:59.990')]
final_phase_global_mc2 = df[(df['Phase'] != 'Group Stage') & (df['MC2'] != '1900-01-01 00:09:59.990')]
final_phase_global_ci1 = df[(df['Phase'] != 'Group Stage') & (df['CI1'] != '1900-01-01 00:09:59.990')]
final_phase_global_gv2 = df[(df['Phase'] != 'Group Stage') & (df['GV2'] != '1900-01-01 00:09:59.990')]
final_phase_global_dp2 = df[(df['Phase'] != 'Group Stage') & (df['DP2'] != '1900-01-01 00:09:59.990')]
final_phase_global_bc2 = df[(df['Phase'] != 'Group Stage') & (df['BC2'] != '1900-01-01 00:09:59.990')]
final_phase_global_mc3 = df[(df['Phase'] != 'Group Stage') & (df['MC3'] != '1900-01-01 00:09:59.990')]
final_phase_global_kb1 = df[(df['Phase'] != 'Group Stage') & (df['KB1'] != '1900-01-01 00:09:59.990')]
final_phase_global_ci2 = df[(df['Phase'] != 'Group Stage') & (df['CI2'] != '1900-01-01 00:09:59.990')]
final_phase_global_vl1 = df[(df['Phase'] != 'Group Stage') & (df['VL1'] != '1900-01-01 00:09:59.990')]
final_phase_global_bc3 = df[(df['Phase'] != 'Group Stage') & (df['BC3'] != '1900-01-01 00:09:59.990')]
final_phase_global_mc4 = df[(df['Phase'] != 'Group Stage') & (df['MC4'] != '1900-01-01 00:09:59.990')]
final_phase_global_dp3 = df[(df['Phase'] != 'Group Stage') & (df['DP3'] != '1900-01-01 00:09:59.990')]
final_phase_global_kb2 = df[(df['Phase'] != 'Group Stage') & (df['KB2'] != '1900-01-01 00:09:59.990')]
final_phase_global_gv3 = df[(df['Phase'] != 'Group Stage') & (df['GV3'] != '1900-01-01 00:09:59.990')]
final_phase_global_vl2 = df[(df['Phase'] != 'Group Stage') & (df['VL2'] != '1900-01-01 00:09:59.990')]
final_phase_global_rr = df[(df['Phase'] != 'Group Stage') & (df['RR'] != '1900-01-01 00:09:59.990')]

# %%
# MIN et Max des Phases finales
# Instanciation des variables sous forme de string
mc1_min_final_phase_global_string = str(final_phase_global_mc1['MC1'].min())
mc1_max_final_phase_global_string = str(final_phase_global_mc1['MC1'].max())
mc1_mean_final_phase_global_string = str(final_phase_global_mc1['MC1'].mean())
dp1_min_final_phase_global_string = str(final_phase_global_dp1['DP1'].min())
dp1_max_final_phase_global_string = str(final_phase_global_dp1['DP1'].max())
dp1_mean_final_phase_global_string = str(final_phase_global_dp1['DP1'].mean())
gv1_min_final_phase_global_string = str(final_phase_global_gv1['GV1'].min())
gv1_max_final_phase_global_string = str(final_phase_global_gv1['GV1'].max())
gv1_mean_final_phase_global_string = str(final_phase_global_gv1['GV1'].mean())
bc1_min_final_phase_global_string = str(final_phase_global_bc1['BC1'].min())
bc1_max_final_phase_global_string = str(final_phase_global_bc1['BC1'].max())
bc1_mean_final_phase_global_string = str(final_phase_global_bc1['BC1'].mean())
mc2_min_final_phase_global_string = str(final_phase_global_mc2['MC2'].min())
mc2_max_final_phase_global_string = str(final_phase_global_mc2['MC2'].max())
mc2_mean_final_phase_global_string = str(final_phase_global_mc2['MC2'].mean())
ci1_min_final_phase_global_string = str(final_phase_global_ci1['CI1'].min())
ci1_max_final_phase_global_string = str(final_phase_global_ci1['CI1'].max())
ci1_mean_final_phase_global_string = str(final_phase_global_ci1['CI1'].mean())
gv2_min_final_phase_global_string = str(final_phase_global_gv2['GV2'].min())
gv2_max_final_phase_global_string = str(final_phase_global_gv2['GV2'].max())
gv2_mean_final_phase_global_string = str(final_phase_global_gv2['GV2'].mean())
dp2_min_final_phase_global_string = str(final_phase_global_dp2['DP2'].min())
dp2_max_final_phase_global_string = str(final_phase_global_dp2['DP2'].max())
dp2_mean_final_phase_global_string = str(final_phase_global_dp2['DP2'].mean())
bc2_min_final_phase_global_string = str(final_phase_global_bc2['BC2'].min())
bc2_max_final_phase_global_string = str(final_phase_global_bc2['BC2'].max())
bc2_mean_final_phase_global_string = str(final_phase_global_bc2['BC2'].mean())
mc3_min_final_phase_global_string = str(final_phase_global_mc3['MC3'].min())
mc3_max_final_phase_global_string = str(final_phase_global_mc3['MC3'].max())
mc3_mean_final_phase_global_string = str(final_phase_global_mc3['MC3'].mean())
kb1_min_final_phase_global_string = str(final_phase_global_kb1['KB1'].min())
kb1_max_final_phase_global_string = str(final_phase_global_kb1['KB1'].max())
kb1_mean_final_phase_global_string = str(final_phase_global_kb1['KB1'].mean())
ci2_min_final_phase_global_string = str(final_phase_global_ci2['CI2'].min())
ci2_max_final_phase_global_string = str(final_phase_global_ci2['CI2'].max())
ci2_mean_final_phase_global_string = str(final_phase_global_ci2['CI2'].mean())
vl1_min_final_phase_global_string = str(final_phase_global_vl1['VL1'].min())
vl1_max_final_phase_global_string = str(final_phase_global_vl1['VL1'].max())
vl1_mean_final_phase_global_string = str(final_phase_global_vl1['VL1'].mean())
bc3_min_final_phase_global_string = str(final_phase_global_bc3['BC3'].min())
bc3_max_final_phase_global_string = str(final_phase_global_bc3['BC3'].max())
bc3_mean_final_phase_global_string = str(final_phase_global_bc3['BC3'].mean())
mc4_min_final_phase_global_string = str(final_phase_global_mc4['MC4'].min())
mc4_max_final_phase_global_string = str(final_phase_global_mc4['MC4'].max())
mc4_mean_final_phase_global_string = str(final_phase_global_mc4['MC4'].mean())
dp3_min_final_phase_global_string = str(final_phase_global_dp3['DP3'].min())
dp3_max_final_phase_global_string = str(final_phase_global_dp3['DP3'].max())
dp3_mean_final_phase_global_string = str(final_phase_global_dp3['DP3'].mean())
kb2_min_final_phase_global_string = str(final_phase_global_kb2['KB2'].min())
kb2_max_final_phase_global_string = str(final_phase_global_kb2['KB2'].max())
kb2_mean_final_phase_global_string = str(final_phase_global_kb2['KB2'].mean())
gv3_min_final_phase_global_string = str(final_phase_global_gv3['GV3'].min())
gv3_max_final_phase_global_string = str(final_phase_global_gv3['GV3'].max())
gv3_mean_final_phase_global_string = str(final_phase_global_gv3['GV3'].mean())
vl2_min_final_phase_global_string = str(final_phase_global_vl2['VL2'].min())
vl2_max_final_phase_global_string = str(final_phase_global_vl2['VL2'].max())
vl2_mean_final_phase_global_string = str(final_phase_global_vl2['VL2'].mean())
rr_min_final_phase_global_string = str(final_phase_global_rr['RR'].min())
rr_max_final_phase_global_string = str(final_phase_global_rr['RR'].max())
rr_mean_final_phase_global_string = str(final_phase_global_rr['RR'].mean())

# %%
# Instanciation des variables avec uniquement les plages de caractères voulus
mc1_min_final_phase_global = mc1_min_final_phase_global_string[14:-4]
mc1_max_final_phase_global = mc1_max_final_phase_global_string[14:-4]
mc1_mean_final_phase_global = mc1_mean_final_phase_global_string[14:-7]
dp1_min_final_phase_global = dp1_min_final_phase_global_string[14:-4]
dp1_max_final_phase_global = dp1_max_final_phase_global_string[14:-4]
dp1_mean_final_phase_global = dp1_mean_final_phase_global_string[14:-7]
gv1_min_final_phase_global = gv1_min_final_phase_global_string[14:-4]
gv1_max_final_phase_global = gv1_max_final_phase_global_string[14:-4]
gv1_mean_final_phase_global = gv1_mean_final_phase_global_string[14:-7]
bc1_min_final_phase_global = bc1_min_final_phase_global_string[14:-4]
bc1_max_final_phase_global = bc1_max_final_phase_global_string[14:-4]
bc1_mean_final_phase_global = bc1_mean_final_phase_global_string[14:-7]
mc2_min_final_phase_global = mc2_min_final_phase_global_string[14:-4]
mc2_max_final_phase_global = mc2_max_final_phase_global_string[14:-4]
mc2_mean_final_phase_global = mc2_mean_final_phase_global_string[14:-7]
ci1_min_final_phase_global = ci1_min_final_phase_global_string[14:-4]
ci1_max_final_phase_global = ci1_max_final_phase_global_string[14:-4]
ci1_mean_final_phase_global = ci1_mean_final_phase_global_string[14:-7]
gv2_min_final_phase_global = gv2_min_final_phase_global_string[14:-4]
gv2_max_final_phase_global = gv2_max_final_phase_global_string[14:-4]
gv2_mean_final_phase_global = gv2_mean_final_phase_global_string[14:-7]
dp2_min_final_phase_global = dp2_min_final_phase_global_string[14:-4]
dp2_max_final_phase_global = dp2_max_final_phase_global_string[14:-4]
dp2_mean_final_phase_global = dp2_mean_final_phase_global_string[14:-7]
bc2_min_final_phase_global = bc2_min_final_phase_global_string[14:-4]
bc2_max_final_phase_global = bc2_max_final_phase_global_string[14:-4]
bc2_mean_final_phase_global = bc2_mean_final_phase_global_string[14:-7]
mc3_min_final_phase_global = mc3_min_final_phase_global_string[14:-4]
mc3_max_final_phase_global = mc3_max_final_phase_global_string[14:-4]
mc3_mean_final_phase_global = mc3_mean_final_phase_global_string[14:-7]
kb1_min_final_phase_global = kb1_min_final_phase_global_string[14:-4]
kb1_max_final_phase_global = kb1_max_final_phase_global_string[14:-4]
kb1_mean_final_phase_global = kb1_mean_final_phase_global_string[14:-7]
ci2_min_final_phase_global = ci2_min_final_phase_global_string[14:-4]
ci2_max_final_phase_global = ci2_max_final_phase_global_string[14:-4]
ci2_mean_final_phase_global = ci2_mean_final_phase_global_string[14:-7]
vl1_min_final_phase_global = vl1_min_final_phase_global_string[14:-4]
vl1_max_final_phase_global = vl1_max_final_phase_global_string[14:-4]
vl1_mean_final_phase_global = vl1_mean_final_phase_global_string[14:-7]
bc3_min_final_phase_global = bc3_min_final_phase_global_string[14:-4]
bc3_max_final_phase_global = bc3_max_final_phase_global_string[14:-4]
bc3_mean_final_phase_global = bc3_mean_final_phase_global_string[14:-7]
mc4_min_final_phase_global = mc4_min_final_phase_global_string[14:-4]
mc4_max_final_phase_global = mc4_max_final_phase_global_string[14:-4]
mc4_mean_final_phase_global = mc4_mean_final_phase_global_string[14:-7]
dp3_min_final_phase_global = dp3_min_final_phase_global_string[14:-4]
dp3_max_final_phase_global = dp3_max_final_phase_global_string[14:-4]
dp3_mean_final_phase_global = dp3_mean_final_phase_global_string[14:-7]
kb2_min_final_phase_global = kb2_min_final_phase_global_string[14:-4]
kb2_max_final_phase_global = kb2_max_final_phase_global_string[14:-4]
kb2_mean_final_phase_global = kb2_mean_final_phase_global_string[14:-7]
gv3_min_final_phase_global = gv3_min_final_phase_global_string[14:-4]
gv3_max_final_phase_global = gv3_max_final_phase_global_string[14:-4]
gv3_mean_final_phase_global = gv3_mean_final_phase_global_string[14:-7]
vl2_min_final_phase_global = vl2_min_final_phase_global_string[14:-4]
vl2_max_final_phase_global = vl2_max_final_phase_global_string[14:-4]
vl2_mean_final_phase_global = vl2_mean_final_phase_global_string[14:-7]
rr_min_final_phase_global = rr_min_final_phase_global_string[14:-4]
rr_max_final_phase_global = rr_max_final_phase_global_string[14:-4]
rr_mean_final_phase_global = rr_mean_final_phase_global_string[14:-7]

# %%
print(f'Best One-Try done at Mario Circuit 1 in SMK one-try World Championships (Final Phase): "{mc1_min_final_phase_global}".')
print(f'Worst One-Try done at Mario Circuit 1 in SMK one-try World Championships (Final Phase) "{mc1_max_final_phase_global}".')
print(f'Mean of MC1 times in SMK one-try World Championships (Final Phase): "{mc1_mean_final_phase_global}".\n')

print(f'Best One-Try done at Donut Plains 1 in SMK one-try World Championships (Final Phase) "{dp1_min_final_phase_global}".')
print(f'Worst One-Try done at Donut Plains 1 in SMK one-try World Championships (Final Phase) "{dp1_max_final_phase_global}".')
print(f'Mean of DP1 times in SMK one-try World Championships (Final Phase): "{dp1_mean_final_phase_global}".\n')

print(f'Best One-Try done at Ghost Valley 1 in SMK one-try World Championships (Final Phase) "{gv1_min_final_phase_global}".')
print(f'Worst One-Try done at Ghost Valley 1 in SMK one-try World Championships (Final Phase) "{gv1_max_final_phase_global}".')
print(f'Mean of GV1 times in SMK one-try World Championships (Final Phase): "{gv1_mean_final_phase_global}".\n')

print(f'Best One-Try done at Bowser Castle 1 in SMK one-try World Championships (Final Phase) "{bc1_min_final_phase_global}".')
print(f'Worst One-Try done at Bowser Castle 1 in SMK one-try World Championships (Final Phase) "{bc1_max_final_phase_global}".')
print(f'Mean of BC1 times in SMK one-try World Championships (Final Phase): "{bc1_mean_final_phase_global}".\n')


print(f'Best One-Try done at Mario Circuit 2 in SMK one-try World Championships (Final Phase) "{mc2_min_final_phase_global}".')
print(f'Worst One-Try done at Mario Circuit 2 in SMK one-try World Championships (Final Phase) "{mc2_max_final_phase_global}".')
print(f'Mean of MC2 times in SMK one-try World Championships (Final Phase): "{mc2_mean_final_phase_global}".\n')

print(f'Best One-Try done at Choco Island 1 in SMK one-try World Championships (Final Phase) "{ci1_min_final_phase_global}".')
print(f'Worst One-Try done at Choco Island 1 in SMK one-try World Championships (Final Phase) "{ci1_max_final_phase_global}".')
print(f'Mean of CI1 times in SMK one-try World Championships (Final Phase): "{ci1_mean_final_phase_global}".\n')

print(f'Best One-Try done at Ghost Valley 2 in SMK one-try World Championships (Final Phase) "{gv2_min_final_phase_global}".')
print(f'Worst One-Try done at Ghost Valley 2 in SMK one-try World Championships (Final Phase) "{gv2_max_final_phase_global}".')
print(f'Mean of GV2 times in SMK one-try World Championships (Final Phase): "{gv2_mean_final_phase_global}".\n')

print(f'Best One-Try done at Donut plains 2 in SMK one-try World Championships (Final Phase) "{dp2_min_final_phase_global}".')
print(f'Worst One-Try done at Donut plains 2 in SMK one-try World Championships (Final Phase) "{dp2_max_final_phase_global}".')
print(f'Mean of DP2 times in SMK one-try World Championships (Final Phase): "{dp2_mean_final_phase_global}".\n')

print(f'Best One-Try done at Bowser Castle 2 in SMK one-try World Championships (Final Phase) "{bc2_min_final_phase_global}".')
print(f'Worst One-Try done at Bowser Castle 2 in SMK one-try World Championships (Final Phase) "{bc2_max_final_phase_global}".')
print(f'Mean of BC2 times in SMK one-try World Championships (Final Phase): "{bc2_mean_final_phase_global}".\n')

print(f'Best One-Try done at Mario Circuit 3 in SMK one-try World Championships (Final Phase) "{mc3_min_final_phase_global}".')
print(f'Worst One-Try done at Mario Circuit 3 in SMK one-try World Championships (Final Phase) "{mc3_max_final_phase_global}".')
print(f'Mean of MC3 times in SMK one-try World Championships (Final Phase): "{mc3_mean_final_phase_global}".\n')

print(f'Best One-Try done at Koopa Beach 1 in SMK one-try World Championships (Final Phase) "{kb1_min_final_phase_global}".')
print(f'Worst One-Try done at Koopa Beach 1  in SMK one-try World Championships (Final Phase) "{kb1_max_final_phase_global}".')
print(f'Mean of KB1 times in SMK one-try World Championships (Final Phase): "{kb1_mean_final_phase_global}".\n')

print(f'Best One-Try done at Choco Island 2 in SMK one-try World Championships (Final Phase) "{ci2_min_final_phase_global}".')
print(f'Worst One-Try done at Choco Island 2 in SMK one-try World Championships (Final Phase) "{ci2_max_final_phase_global}".')
print(f'Mean of CI2 times in SMK one-try World Championships (Final Phase): "{ci2_mean_final_phase_global}".\n')

print(f'Best One-Try done at Vanilla Lake 1 in SMK one-try World Championships (Final Phase) "{vl1_min_final_phase_global}".')
print(f'Worst One-Try done at Vanilla Lake 1 in SMK one-try World Championships (Final Phase) "{vl1_max_final_phase_global}".')
print(f'Mean of VL1 times in SMK one-try World Championships (Final Phase): "{vl1_mean_final_phase_global}".\n')

print(f'Best One-Try done at Bowser Castle 3 in SMK one-try World Championships (Final Phase) "{bc3_min_final_phase_global}".')
print(f'Worst One-Try done at Bowser Castle 3 in SMK one-try World Championships (Final Phase) "{bc3_max_final_phase_global}".')
print(f'Mean of BC3 times in SMK one-try World Championships (Final Phase): "{bc3_mean_final_phase_global}".\n')

print(f'Best One-Try done at Mario Circuit 4 in SMK one-try World Championships (Final Phase) "{mc4_min_final_phase_global}".')
print(f'Worst One-Try done at Mario Circuit 4 in SMK one-try World Championships (Final Phase) "{mc4_max_final_phase_global}".')
print(f'Mean of MC4 times in SMK one-try World Championships (Final Phase): "{mc4_mean_final_phase_global}".\n')

print(f'Best One-Try done at Donut plains 3 in SMK one-try World Championships (Final Phase) "{dp3_min_final_phase_global}".')
print(f'Worst One-Try done at Donut plains 3  in SMK one-try World Championships (Final Phase) "{dp3_max_final_phase_global}".')
print(f'Mean of DP3 times in SMK one-try World Championships (Final Phase): "{dp3_mean_final_phase_global}".\n')

print(f'Best One-Try done at Koopa Beach 2 in SMK one-try World Championships (Final Phase) "{kb2_min_final_phase_global}".')
print(f'Worst One-Try done at Koopa Beach 2  in SMK one-try World Championships (Final Phase) "{kb2_max_final_phase_global}".')
print(f'Mean of KB2 times in SMK one-try World Championships (Final Phase): "{kb2_mean_final_phase_global }".\n')

print(f'Best One-Try done at Ghost Valley 3 in SMK one-try World Championships (Final Phase) "{gv3_min_final_phase_global}".')
print(f'Worst One-Try done at Ghost Valley 3 in SMK one-try World Championships (Final Phase) "{gv3_max_final_phase_global}".')
print(f'Mean of GV3 times in SMK one-try World Championships (Final Phase): "{gv3_mean_final_phase_global}".\n')

print(f'Best One-Try done at Vanilla Lake 2 in SMK one-try World Championships (Final Phase) "{vl2_min_final_phase_global}".')
print(f'Worst One-Try done at Vanilla Lake 2 in SMK one-try World Championships (Final Phase) "{vl2_max_final_phase_global}".')
print(f'Mean of VL2 times in SMK one-try World Championships (Final Phase): "{vl2_mean_final_phase_global}".\n')

print(f'Best One-Try done at Rainbow Road in SMK one-try World Championships (Final Phase) "{rr_min_final_phase_global}".')
print(f'Worst One-Try done at Rainbow Road in SMK one-try World Championships (Final Phase) "{rr_max_final_phase_global}".')
print(f'Mean of RR times in SMK one-try World Championships (Final Phase): "{rr_mean_final_phase_global}".\n')
# Out:
# Best One-Try done at Mario Circuit 1 in SMK one-try World Championships (Final Phase): "00:59.14".
# Worst One-Try done at Mario Circuit 1 in SMK one-try World Championships (Final Phase) "01:13.21".
# Mean of MC1 times in SMK one-try World Championships (Final Phase): "01:02.26".
#
# Best One-Try done at Donut Plains 1 in SMK one-try World Championships (Final Phase) "01:11.79".
# Worst One-Try done at Donut Plains 1 in SMK one-try World Championships (Final Phase) "01:17.94".
# Mean of DP1 times in SMK one-try World Championships (Final Phase): "01:15.08".
#
# Best One-Try done at Ghost Valley 1 in SMK one-try World Championships (Final Phase) "01:06.60".
# Worst One-Try done at Ghost Valley 1 in SMK one-try World Championships (Final Phase) "01:45.72".
# Mean of GV1 times in SMK one-try World Championships (Final Phase): "01:10.78".
#
# Best One-Try done at Bowser Castle 1 in SMK one-try World Championships (Final Phase) "01:29.33".
# ...

# %% [markdown]
# #### Analyse par la comparaison des min/max/mean par rapport aux différents stades de la compétition

# %% [markdown]
# ##### 1) Exemple pour Mario Circuit 1 (MC1)

# %%
# Min des différents stades analysés
print(f'Best One-Try done at Mario Circuit 1 in World Championships between 2012 and 2019: "{mc1_min}".')
print(f'Best One-Try done at Mario Circuit 1 in World Championships for Top 16 Group Stage members: "{mc1_min_top16}".')
print(f'Best One-Try done at Mario Circuit 1 in World Championships for Top 8 Group Stage members: "{mc1_min_top8}".')
print(f'Best One-Try done at Mario Circuit 1 in SMK one-try World Championships (Final Phase): "{mc1_min_final_phase_global}".')
# Out:
# Best One-Try done at Mario Circuit 1 in World Championships between 2012 and 2019: "00:58.96".
# Best One-Try done at Mario Circuit 1 in World Championships for Top 16 Group Stage members: "00:58.96".
# Best One-Try done at Mario Circuit 1 in World Championships for Top 8 Group Stage members: "00:58.96".
# Best One-Try done at Mario Circuit 1 in SMK one-try World Championships (Final Phase): "00:59.14".

# %% [markdown]
# ##### Commentaires:
# - On peut facilement déduire que le meilleur chono réalisé l'a été par un membre ayant fini dans les 8 premiers de la phase de poule.
# - On peut voir que le meilleur chrono en phase de poule est meilleur que le meilleur chrono en phase finale, ce qui est logique dans la mesure ou les top players savent qu'ils vont se qualifier dans le top 16. Il prennent donc plus de risques en poule pour essayer d'obtenir le meilleur chrono possible en un seul essai.

# %%
# Max des différents stades analysés
print(f'Worst One-Try done at Mario Circuit 1 in World Championships between 2012 and 2019: "{mc1_max}".')
print(f'Worst One-Try done at Mario Circuit 1 in World Championships for Top 16 Group Stage members: "{mc1_max_top16}".')
print(f'Worst One-Try done at Mario Circuit 1 in World Championships for Top 8 Group Stage members: "{mc1_max_top8}".')
print(f'Worst One-Try done at Mario Circuit 1 in SMK one-try World Championships (Final Phase) "{mc1_max_final_phase_global}".')
# Out:
# Worst One-Try done at Mario Circuit 1 in World Championships between 2012 and 2019: "01:30.36".
# Worst One-Try done at Mario Circuit 1 in World Championships for Top 16 Group Stage members: "01:06.50".
# Worst One-Try done at Mario Circuit 1 in World Championships for Top 8 Group Stage members: "01:05.68".
# Worst One-Try done at Mario Circuit 1 in SMK one-try World Championships (Final Phase) "01:13.21".

# %% [markdown]
# ##### Commentaires:
# - En phase de poule, on voit bien que plus on monte dans le classement de la poule, moins le max est élevé.
# - En phase finale, le max est plus élevé que pour le top 16 ou top 8. Hypothèse: Contreperformance liée à une prise de risque trop élevée,Contreperformance tout court, ou problème de gestion de la pression à ce stade de la compétition.

# %%
# Mean des différents stades de la compétition.
print(f'Mean of all Mario Circuit 1 times in World Championships between 2012 and 2019: "{mc1_mean}".')
print(f'Mean of Mario Circuit 1 times in World Championships for Top 16 Group Stage members: "{mc1_mean_top16}".')
print(f'Mean of Mario Circuit 1 times in World Championships for Top 8 Group Stage members: "{mc1_mean_top8}".')
print(f'Mean of MC1 times in SMK one-try World Championships (Final Phase): "{mc1_mean_final_phase_global}".')
# Out:
# Mean of all Mario Circuit 1 times in World Championships between 2012 and 2019: "01:05.23".
# Mean of Mario Circuit 1 times in World Championships for Top 16 Group Stage members: "01:01.66".
# Mean of Mario Circuit 1 times in World Championships for Top 8 Group Stage members: "01:00.63".
# Mean of MC1 times in SMK one-try World Championships (Final Phase): "01:02.26".

# %% [markdown]
# ##### Commentaires:
# - Plus on monte dans le top des poules, plus basse est la moyenne générale.
# - En phase finale, la moyenne est plus élevée. Hypothèse: Contreperformance liée à une prise de risque trop élevée,Contreperformance tout court, ou problème de gestion de la pression à ce stade de la compétition.

# %% [markdown]
# #### 2) Exemple pour Ghost Valley 1 (GV1)

# %%
# Min des différents stades analysés
print(f'Best One-Try done at Ghost Valley 1 in World Championships between 2012 and 2019: "{gv1_min}".')
print(f'Best One-Try done at Ghost Valley 1 in World Championships for Top 16 Group Stage members: "{gv1_min_top16}".')
print(f'Best One-Try done at Ghost Valley 1 in World Championships for Top 8 Group Stage members: "{gv1_min_top8}".')
print(f'Best One-Try done at Ghost Valley 1 in SMK one-try World Championships (Final Phase): "{gv1_min_final_phase_global}".')
# Out:
# Best One-Try done at Ghost Valley 1 in World Championships between 2012 and 2019: "01:06.54".
# Best One-Try done at Ghost Valley 1 in World Championships for Top 16 Group Stage members: "01:06.54".
# Best One-Try done at Ghost Valley 1 in World Championships for Top 8 Group Stage members: "01:06.54".
# Best One-Try done at Ghost Valley 1 in SMK one-try World Championships (Final Phase): "01:06.60".

# %% [markdown]
# ##### Commentaires:
# - On constate ici que le min en phase de poule est quasi-similaire à celui de la phase finale.

# %%
# Max des différents stades analysés
print(f'Worst One-Try done at Ghost Valley 1 in World Championships between 2012 and 2019: "{gv1_max}".')
print(f'Worst One-Try done at Ghost Valley 1 in World Championships for Top 16 Group Stage members: "{gv1_max_top16}".')
print(f'Worst One-Try done at Ghost Valley 1 in World Championships for Top 8 Group Stage members: "{gv1_max_top8}".')
print(f'Worst One-Try done at Ghost Valley 1 in SMK one-try World Championships (Final Phase) "{gv1_max_final_phase_global}".')
# Out:
# Worst One-Try done at Ghost Valley 1 in World Championships between 2012 and 2019: "02:08.61".
# Worst One-Try done at Ghost Valley 1 in World Championships for Top 16 Group Stage members: "01:17.41".
# Worst One-Try done at Ghost Valley 1 in World Championships for Top 8 Group Stage members: "01:13.59".
# Worst One-Try done at Ghost Valley 1 in SMK one-try World Championships (Final Phase) "01:45.72".

# %% [markdown]
# ##### Commentaires:
# - Même phénomène que pour Mario Circuit 1 (plus on monte dans le classement de la poule, moins le max est élevé.)

# %%
# Mean des différents stades de la compétition.
print(f'Mean of all Ghost Valley 1 times in World Championships between 2012 and 2019: "{gv1_mean}".')
print(f'Mean of Ghost Valley 1 times in World Championships for Top 16 Group Stage members: "{gv1_mean_top16}".')
print(f'Mean of Ghost Valley 1 times in World Championships for Top 8 Group Stage members: "{gv1_mean_top8}".')
print(f'Mean of Ghost Valley 1 times in SMK one-try World Championships (Final Phase): "{gv1_mean_final_phase_global}".')
# Out:
# Mean of all Ghost Valley 1 times in World Championships between 2012 and 2019: "01:36.15".
# Mean of Ghost Valley 1 times in World Championships for Top 16 Group Stage members: "01:08.90".
# Mean of Ghost Valley 1 times in World Championships for Top 8 Group Stage members: "01:08.43".
# Mean of Ghost Valley 1 times in SMK one-try World Championships (Final Phase): "01:10.78".

# %% [markdown]
# ##### Commentaires:
# - Même phénomène que pour Mario Circuit 1 (En phase finale, la moyenne est plus élevée. Hypothèse: Contreperformance liée à une prise de risque trop élevée,Contreperformance tout court, ou problème de gestion de la pression à ce stade de la compétition.).

# %% [markdown]
# #### CONCLUSION:
# - Les meilleurs chronos sont réalisés majoritairement en phase de poule, là où la pression est moins forte.
# - A contrario, la moyenne en phase finale est moins élevée que la moyenne d'un top 16 ou top 8 en phase de poule, car des éléments supplémentaires entrent en jeu (prise de risque pour se qualifier au stade suivant, gestion de la pression à haut niveau).

# %% [markdown]
# ##### Autres Stats

# %%
# Stats sur le nombre de fois ou une course est tombée en phase finale
nb_time_tracks_final_phase = df['Final Phase Tracks'].value_counts()
nb_time_tracks_final_phase
# Out:
# -      512
# CI2      6
# DP2      5
# BC2      4
# GV1      4
# BC1      4
# MC1      4
# MC4      4
# GV3      4
# MC2      4
# KB1      4
# GV2      4
# KB2      4
# BC3      3
# VL1      3
# RR       3
# VL2      3
# MC3      3
# DP3      3
# DP1      1
# CI1      1
# Name: Final Phase Tracks, dtype: int64

# %% [markdown]
# #### Commentaires:
# - Ici, on voit que CI2 (Choco Island 2) est la course qui a été le plus tirée au sort lors des phases finales
# (75 % du temps), alors que DP1 et CI1 sont à contrario les courses les moins tirées au sort ces 8 dernières années(12,5% du temps seulement)
# - Pic: CI2 (6 fois)
# - Hors norme +: DP2(5 fois)
# - Norme: 4 et 3 fois en moyenne
# - Hors norme - : DP1, CI1
