# %% [markdown]
# ## 03 - TOP 16 GROUP STAGE DISTRIBUTION

# %% [markdown]
# <img src="tt_01.jpg">

# %% [markdown]
# #### LIBRARY IMPORTS

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# #### LOAD FILE

# %%
df = pd.read_csv('smk_stats_v10.csv', sep = ';', encoding = 'iso-8859-1')

# %% [markdown]
# #### Data preparation

# %%
# TRANSFORMATION DES COLONNES 2 à 24 en Datetime pour pouvoir prendre en compte les chronos.
df['MC1'] = pd.to_datetime(df['MC1'], format='%M:%S,%f')
df['DP1'] = pd.to_datetime(df['DP1'], format='%M:%S,%f')
df['GV1'] = pd.to_datetime(df['GV1'], format='%M:%S,%f')
df['BC1'] = pd.to_datetime(df['BC1'], format='%M:%S,%f')
df['MC2'] = pd.to_datetime(df['MC2'], format='%M:%S,%f')
df['CI1'] = pd.to_datetime(df['CI1'], format='%M:%S,%f')
df['GV2'] = pd.to_datetime(df['GV2'], format='%M:%S,%f')
df['DP2'] = pd.to_datetime(df['DP2'], format='%M:%S,%f')
df['BC2'] = pd.to_datetime(df['BC2'], format='%M:%S,%f')
df['MC3'] = pd.to_datetime(df['MC3'], format='%M:%S,%f')
df['KB1'] = pd.to_datetime(df['KB1'], format='%M:%S,%f')
df['CI2'] = pd.to_datetime(df['CI2'], format='%M:%S,%f')
df['VL1'] = pd.to_datetime(df['VL1'], format='%M:%S,%f')
df['BC3'] = pd.to_datetime(df['BC3'], format='%M:%S,%f')
df['MC4'] = pd.to_datetime(df['MC4'], format='%M:%S,%f')
df['DP3'] = pd.to_datetime(df['DP3'], format='%M:%S,%f')
df['KB2'] = pd.to_datetime(df['KB2'], format='%M:%S,%f')
df['GV3'] = pd.to_datetime(df['GV3'], format='%M:%S,%f')
df['VL2'] = pd.to_datetime(df['VL2'], format='%M:%S,%f')
df['RR'] = pd.to_datetime(df['RR'], format='%M:%S,%f')
df['Total Time'] = pd.to_datetime(df['Total Time'], format='%M:%S,%f')

# %%
# Identifier les membres du top 16 et les instancier -> Colonnes Phase ou Position peuvent nous aider
top_16_global = df[(df['Phase'] == 'Group Stage') & (df['Position'] < 17)]
top_16_global.tail(5)
# Out:
#                       Name     Nickname Country                     MC1  \
# 522  Frédéric Duarte-Leite    Fredyball      FR 1900-01-01 00:01:01.330
# 523             David Moll  Danger Moll      UK 1900-01-01 00:01:01.550
# 524        Florian Chollet       Flo233      FR 1900-01-01 00:01:02.720
# 525                 Clbrun       Clbrun     SWZ 1900-01-01 00:01:03.120
# 526         Christian Wild      Chraizy     GER 1900-01-01 00:01:01.430
#
#                         DP1                     GV1                     BC1  \
# 522 1900-01-01 00:01:16.370 1900-01-01 00:01:08.490 1900-01-01 00:01:39.790
# 523 1900-01-01 00:01:16.170 1900-01-01 00:01:09.270 1900-01-01 00:01:33.110
# 524 1900-01-01 00:01:16.770 1900-01-01 00:01:08.810 1900-01-01 00:01:36.170
# 525 1900-01-01 00:01:20.110 1900-01-01 00:01:12.030 1900-01-01 00:01:42.220
# 526 1900-01-01 00:01:22.120 1900-01-01 00:01:12.310 1900-01-01 00:01:38.780
#
# ...

# %%
top_16_global.shape # Si la shape = 128 c'est ok.
# Out:
# (128, 37)

# %% [markdown]
# ### 2) -	Analyser la distribution des données par course en phase de poule pour le top 16 (globale, puis par année)

# %% [markdown]
# ##### A) Globale

# %%
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top_16_global['MC1'],bins=9,facecolor='black', ec='black', alpha = 0.5)
plt.style.use('seaborn-white')
plt.title('MC1 (Top 16 Distribution - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top_16_global['DP1'], bins=15, facecolor='green',ec='black', alpha = 0.6)
plt.title('DP1 (Top 16 Distribution - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top_16_global['GV1'], bins=12, facecolor='brown',ec='black', alpha = 0.8)
plt.title('GV1 (Top 16 Distribution - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top_16_global['BC1'], bins=22, facecolor='red',ec='black', alpha = 0.7)
plt.title('BC1 (Top 16 Distribution - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top_16_global['MC2'], bins=23, facecolor='black',ec='black', alpha=0.5)
plt.title('MC2 (Top 16 Distribution - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top_16_global['CI1'], bins=18, facecolor='orange',ec='black', alpha = 0.5)
plt.title('CI1 (Top 16 Distribution - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top_16_global['GV2'], bins=23, facecolor='brown',ec='black', alpha=0.8)
plt.title('GV2 (Top 16 Distribution - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top_16_global['DP2'], bins=15, facecolor='green',ec='black', alpha=0.6)
plt.title('DP2 (Top 16 Distribution - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top_16_global['BC2'], bins=29, facecolor='red',ec='black', alpha=0.7)
plt.title('BC2 (Top 16 Distribution - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top_16_global['MC3'], bins=20, facecolor='black',ec='black', alpha=0.5)
plt.title('MC3 (Top 16 Distribution - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top_16_global['KB1'], bins=23, facecolor='blue',ec='black', alpha=0.5)
plt.title('KB1 (Top 16 Distribution - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top_16_global['CI2'], bins=24, facecolor='orange',ec='black', alpha=0.5)
plt.title('CI2 (Top 16 Distribution - Group Stage)', fontweight='bold')

plt.show()

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top_16_global['VL1'], bins=23, facecolor='cyan',ec='black', alpha=0.5)# 137 bins réels
plt.title('VL1 (Top 16 Distribution - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top_16_global['BC3'], bins=28, facecolor='red',ec='black', alpha=0.5)
plt.title('BC3 (Top 16 Distribution - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top_16_global['MC4'], bins=17, facecolor='black',ec='black', alpha=0.5)
plt.title('MC4 (Top 16 Distribution - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top_16_global['DP3'], bins=28, facecolor='green',ec='black', alpha=0.6)
plt.title('DP3 (Top 16 Distribution - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top_16_global['KB2'], bins=48, facecolor='blue',ec='black', alpha=0.5)
plt.title('KB2 (Top 16 Distribution - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top_16_global['GV3'], bins=55, facecolor='brown',ec='black', alpha=0.8)
plt.title('GV3 (Top 16 Distribution - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top_16_global['VL2'], bins=27, facecolor='cyan',ec='black', alpha=0.5)
plt.title('VL2 (Top 16 Distribution - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top_16_global['RR'], bins=16, facecolor='purple',ec='black', alpha=0.6)
plt.title('RR (Top 16 Distribution - Group Stage)', fontweight='bold')

plt.show()

# %% [markdown]
# #### Commentaires:
# - Par rapport à la distribution globale, on constate que les écarts de chono se resserent entre les membres du top 16.
# - BC3 et GV3 sont les courses avec les outliers les plus grands (plus de 30 secondes peuvent séparer le meilleur et le pire chrono réalisé par un top 16 en phase de poule).
# - A contrario, MC1 et GV1 sont les 2 circuits où les chronos ont les écarts les plus proches en terme de secondes.

# %% [markdown]
# ##### B)  Chaque course Par Année (Phase de poule, Top 16)

# %%
# Il faut instancier une variable par année de 2012 à 2019 pour le top 16 de chaque année en phase de poule.
top16_2012 = df[(df['Phase'] == 'Group Stage') & (df['Year'] == 2012) & (df['Position'] < 17)]
top16_2013 = df[(df['Phase'] == 'Group Stage') & (df['Year'] == 2013) & (df['Position'] < 17)]
top16_2014 = df[(df['Phase'] == 'Group Stage') & (df['Year'] == 2014) & (df['Position'] < 17)]
top16_2015 = df[(df['Phase'] == 'Group Stage') & (df['Year'] == 2015) & (df['Position'] < 17)]
top16_2016 = df[(df['Phase'] == 'Group Stage') & (df['Year'] == 2016) & (df['Position'] < 17)]
top16_2017 = df[(df['Phase'] == 'Group Stage') & (df['Year'] == 2017) & (df['Position'] < 17)]
top16_2018 = df[(df['Phase'] == 'Group Stage') & (df['Year'] == 2018) & (df['Position'] < 17)]
top16_2019 = df[(df['Phase'] == 'Group Stage') & (df['Year'] == 2019) & (df['Position'] < 17)]

# %%
# Verification du shape (ligne = 16 et colonnes = 29 pour chaque année)
top16_2019.shape
# Out:
# (16, 37)

# %% [markdown]
# ##### Commentaire général:
# - Ici, on représente la distribution des chronos pour le top 16 par année pour chaque circuit pendant la phase de poule.
# - Cette représentation permet de voir à quels niveaux se situent les chronos des 16 meilleurs joueurs des phases de poule par année, et si une évolution/régression/stagnation des chronos est constatée entre 2012 et 2019.

# %%
# PLOT MC1(2012-2019)
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2019['MC1'],bins=5,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC1 (Top 16 Distribution - 2019 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2018['MC1'], bins=4, facecolor='black',ec='black', alpha = 0.5)
plt.title('MC1 (Top 16 Distribution - 2018 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2017['MC1'], bins=6, facecolor='black',ec='black', alpha = 0.5)
plt.title('MC1 (Top 16 Distribution - 2017 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2016['MC1'], bins=6, facecolor='black',ec='black', alpha = 0.5)
plt.title('MC1 (Top 16 Distribution - 2016 - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2015['MC1'], bins=7, facecolor='black',ec='black', alpha=0.5)
plt.title('MC1(Top 16 Distribution - 2015 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2014['MC1'], bins=6, facecolor='black',ec='black', alpha = 0.5)
plt.title('MC1 (Top 16 Distribution - 2014 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2013['MC1'], bins=6, facecolor='black',ec='black', alpha=0.5)
plt.title('MC1 (Top 16 Distribution - 2013 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2012['MC1'], bins=6, facecolor='black',ec='black', alpha=0.5)
plt.title('MC1 (Top 16 Distribution - 2012 - Group Stage)', fontweight='bold')

plt.show()

# %%
# PLOT DP1(2012-2019)
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2019['DP1'],bins=8,facecolor='green', ec='black', alpha = 0.6)
plt.style.use('seaborn-white')
plt.title('DP1 (Top 16 Distribution - 2019 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2018['DP1'],bins=8,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP1 (Top 16 Distribution - 2018 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2017['DP1'],bins=8,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP1 (Top 16 Distribution - 2017 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2016['DP1'],bins=15,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP1 (Top 16 Distribution - 2016 - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2015['DP1'],bins=8,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP1(Top 16 Distribution - 2015 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2014['DP1'],bins=8,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP1 (Top 16 Distribution - 2014 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2013['DP1'],bins=8,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP1 (Top 16 Distribution - 2013 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2012['DP1'],bins=8,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP1 (Top 16 Distribution - 2012 - Group Stage)', fontweight='bold')

plt.show()

# %%
# PLOT GV1(2012-2019)
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2019['GV1'],bins=7,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV1 (Top 16 Distribution - 2019 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2018['GV1'],bins=7,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV1 (Top 16 Distribution - 2018 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2017['GV1'],bins=7,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV1 (Top 16 Distribution - 2017 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2016['GV1'],bins=7,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV1 (Top 16 Distribution - 2016 - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2015['GV1'],bins=7,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV1(Top 16 Distribution - 2015 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2014['GV1'],bins=7,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV1 (Top 16 Distribution - 2014 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2013['GV1'],bins=7,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV1 (Top 16 Distribution - 2013 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2012['GV1'],bins=7,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV1 (Top 16 Distribution - 2012 - Group Stage)', fontweight='bold')

plt.show()

# %%
# PLOT BC1(2012-2019)
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2019['BC1'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC1 (Top 16 Distribution - 2019 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2018['BC1'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC1 (Top 16 Distribution - 2018 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2017['BC1'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC1 (Top 16 Distribution - 2017 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2016['BC1'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC1 (Top 16 Distribution - 2016 - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2015['BC1'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC1(Top 16 Distribution - 2015 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2014['BC1'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC1 (Top 16 Distribution - 2014 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2013['BC1'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC1 (Top 16 Distribution - 2013 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2012['BC1'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC1 (Top 16 Distribution - 2012 - Group Stage)', fontweight='bold')

plt.show()

# %%
# PLOT MC2(2012-2019)
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2019['MC2'],bins=11,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC2 (Top 16 Distribution - 2019 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2018['MC2'],bins=11,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC2 (Top 16 Distribution - 2018 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2017['MC2'],bins=11,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC2 (Top 16 Distribution - 2017 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2016['MC2'],bins=11,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC2 (Top 16 Distribution - 2016 - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2015['MC2'],bins=11,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC2(Top 16 Distribution - 2015 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2014['MC2'],bins=11,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC2 (Top 16 Distribution - 2014 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2013['MC2'],bins=11,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC2 (Top 16 Distribution - 2013 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2012['MC2'],bins=11,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC2 (Top 16 Distribution - 2012 - Group Stage)', fontweight='bold')

plt.show()

# %%
# PLOT CI1(2012-2019)
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2019['CI1'],bins=9,facecolor='orange', ec='black', alpha = 0.5)
plt.title('CI1 (Top 16 Distribution - 2019 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2018['CI1'],bins=9,facecolor='orange', ec='black', alpha = 0.5)
plt.title('CI1 (Top 16 Distribution - 2018 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2017['CI1'],bins=9,facecolor='orange', ec='black', alpha = 0.5)
plt.title('CI1 (Top 16 Distribution - 2017 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2016['CI1'],bins=9,facecolor='orange', ec='black', alpha = 0.5)
plt.title('CI1 (Top 16 Distribution - 2016 - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2015['CI1'],bins=9,facecolor='orange', ec='black', alpha = 0.5)
plt.title('CI1(Top 16 Distribution - 2015 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2014['CI1'],bins=9,facecolor='orange', ec='black', alpha = 0.5)
plt.title('CI1 (Top 16 Distribution - 2014 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2013['CI1'],bins=9,facecolor='orange', ec='black', alpha = 0.5)
plt.title('CI1 (Top 16 Distribution - 2013 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2012['CI1'],bins=9,facecolor='orange', ec='black', alpha = 0.5)
plt.title('CI1 (Top 16 Distribution - 2012 - Group Stage)', fontweight='bold')

plt.show()

# %%
# PLOT GV2(2012-2019)
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2019['GV2'],bins=5,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV2 (Top 16 Distribution - 2019 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2018['GV2'],bins=5,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV2 (Top 16 Distribution - 2018 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2017['GV2'],bins=5,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV2 (Top 16 Distribution - 2017 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2016['GV2'],bins=5,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV2 (Top 16 Distribution - 2016 - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2015['GV2'],bins=5,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV2(Top 16 Distribution - 2015 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2014['GV2'],bins=5,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV2 (Top 16 Distribution - 2014 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2013['GV2'],bins=5,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV2 (Top 16 Distribution - 2013 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2012['GV2'],bins=5,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV2 (Top 16 Distribution - 2012 - Group Stage)', fontweight='bold')

plt.show()

# %%
# PLOT DP2(2012-2019)
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2019['DP2'],bins=7,facecolor='green', ec='black', alpha = 0.6)
plt.style.use('seaborn-white')
plt.title('DP2 (Top 16 Distribution - 2019 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2018['DP2'],bins=7,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP2 (Top 16 Distribution - 2018 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2017['DP2'],bins=7,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP2 (Top 16 Distribution - 2017 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2016['DP2'],bins=7,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP2 (Top 16 Distribution - 2016 - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2015['DP2'],bins=7,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP2(Top 16 Distribution - 2015 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2014['DP2'],bins=7,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP2 (Top 16 Distribution - 2014 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2013['DP2'],bins=7,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP2 (Top 16 Distribution - 2013 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2012['DP2'],bins=7,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP2 (Top 16 Distribution - 2012 - Group Stage)', fontweight='bold')

plt.show()

# %%
# PLOT BC2(2012-2019)
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2019['BC2'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC2 (Top 16 Distribution - 2019 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2018['BC2'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC2 (Top 16 Distribution - 2018 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2017['BC2'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC2 (Top 16 Distribution - 2017 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2016['BC2'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC2 (Top 16 Distribution - 2016 - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2015['BC2'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC2(Top 16 Distribution - 2015 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2014['BC2'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC2 (Top 16 Distribution - 2014 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2013['BC2'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC2 (Top 16 Distribution - 2013 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2012['BC2'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC2 (Top 16 Distribution - 2012 - Group Stage)', fontweight='bold')

plt.show()

# %%
# PLOT MC3(2012-2019)
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2019['MC3'],bins=8,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC3 (Top 16 Distribution - 2019 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2018['MC3'],bins=8,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC3 (Top 16 Distribution - 2018 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2017['MC3'],bins=8,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC3 (Top 16 Distribution - 2017 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2016['MC3'],bins=8,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC3 (Top 16 Distribution - 2016 - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2015['MC3'],bins=8,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC3 (Top 16 Distribution - 2015 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2014['MC3'],bins=8,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC3 (Top 16 Distribution - 2014 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2013['MC3'],bins=8,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC3 (Top 16 Distribution - 2013 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2012['MC3'],bins=8,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC3 (Top 16 Distribution - 2012 - Group Stage)', fontweight='bold')

plt.show()

# %%
# PLOT KB1(2012-2019)
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2019['KB1'],bins=10,facecolor='blue', ec='black', alpha = 0.5)
plt.title('KB1 (Top 16 Distribution - 2019 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2018['KB1'],bins=10,facecolor='blue', ec='black', alpha = 0.5)
plt.title('KB1 (Top 16 Distribution - 2018 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2017['KB1'],bins=10,facecolor='blue', ec='black', alpha = 0.5)
plt.title('KB1 (Top 16 Distribution - 2017 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2016['KB1'],bins=10,facecolor='blue', ec='black', alpha = 0.5)
plt.title('KB1 (Top 16 Distribution - 2016 - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2015['KB1'],bins=10,facecolor='blue', ec='black', alpha = 0.5)
plt.title('KB1 (Top 16 Distribution - 2015 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2014['KB1'],bins=10,facecolor='blue', ec='black', alpha = 0.5)
plt.title('KB1 (Top 16 Distribution - 2014 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2013['KB1'],bins=10,facecolor='blue', ec='black', alpha = 0.5)
plt.title('KB1 (Top 16 Distribution - 2013 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2012['KB1'],bins=10,facecolor='blue', ec='black', alpha = 0.5)
plt.title('KB1 (Top 16 Distribution - 2012 - Group Stage)', fontweight='bold')

plt.show()

# %%
# PLOT CI2(2012-2019)
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2019['CI2'],bins=10,facecolor='orange', ec='black', alpha = 0.5)
plt.title('CI2 (Top 16 Distribution - 2019 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2018['CI2'],bins=10,facecolor='orange', ec='black', alpha = 0.5)
plt.title('CI2 (Top 16 Distribution - 2018 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2017['CI2'],bins=10,facecolor='orange', ec='black', alpha = 0.5)
plt.title('CI2 (Top 16 Distribution - 2017 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2016['CI2'],bins=8,facecolor='orange', ec='black', alpha = 0.5)
plt.title('CI2 (Top 16 Distribution - 2016 - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2015['CI2'],bins=8,facecolor='orange', ec='black', alpha = 0.5)
plt.title('CI2(Top 16 Distribution - 2015 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2014['CI2'],bins=15,facecolor='orange', ec='black', alpha = 0.5)
plt.title('CI2 (Top 16 Distribution - 2014 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2013['CI2'],bins=15,facecolor='orange', ec='black', alpha = 0.5)
plt.title('CI2 (Top 16 Distribution - 2013 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2012['CI2'],bins=15,facecolor='orange', ec='black', alpha = 0.5)
plt.title('CI2 (Top 16 Distribution - 2012 - Group Stage)', fontweight='bold')

plt.show()

# %%
# PLOT VL1(2012-2019)
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2019['VL1'],bins=10,facecolor='cyan', ec='black', alpha = 0.5)
plt.title('VL1 (Top 16 Distribution - 2019 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2018['VL1'],bins=10,facecolor='cyan', ec='black', alpha = 0.5)
plt.title('VL1 (Top 16 Distribution - 2018 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2017['VL1'],bins=10,facecolor='cyan', ec='black', alpha = 0.5)
plt.title('VL1 (Top 16 Distribution - 2017 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2016['VL1'],bins=10,facecolor='cyan', ec='black', alpha = 0.5)
plt.title('VL1 (Top 16 Distribution - 2016 - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2015['VL1'],bins=10,facecolor='cyan', ec='black', alpha = 0.5)
plt.title('VL1 (Top 16 Distribution - 2015 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2014['VL1'],bins=10,facecolor='cyan', ec='black', alpha = 0.5)
plt.title('VL1 (Top 16 Distribution - 2014 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2013['VL1'],bins=10,facecolor='cyan', ec='black', alpha = 0.5)
plt.title('VL1 (Top 16 Distribution - 2013 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2012['VL1'],bins=10,facecolor='cyan', ec='black', alpha = 0.5)
plt.title('VL1 (Top 16 Distribution - 2012 - Group Stage)', fontweight='bold')

plt.show()

# %%
# PLOT BC3(2012-2019)
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2019['BC3'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC3 (Top 16 Distribution - 2019 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2018['BC3'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC3  (Top 16 Distribution - 2018 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2017['BC3'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC3 (Top 16 Distribution - 2017 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2016['BC3'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC3  (Top 16 Distribution - 2016 - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2015['BC3'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC3 (Top 16 Distribution - 2015 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2014['BC3'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC3 (Top 16 Distribution - 2014 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2013['BC3'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC3 (Top 16 Distribution - 2013 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2012['BC3'],bins=10,facecolor='red', ec='black', alpha = 0.7)
plt.title('BC3 (Top 16 Distribution - 2012 - Group Stage)', fontweight='bold')

plt.show()

# %%
# PLOT MC4(2012-2019)
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2019['MC4'],bins=10,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC4 (Top 16 Distribution - 2019 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2018['MC4'],bins=10,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC4 (Top 16 Distribution - 2018 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2017['MC4'],bins=10,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC4 (Top 16 Distribution - 2017 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2016['MC4'],bins=10,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC4 (Top 16 Distribution - 2016 - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2015['MC4'],bins=10,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC4 (Top 16 Distribution - 2015 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2014['MC4'],bins=10,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC4 (Top 16 Distribution - 2014 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2013['MC4'],bins=10,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC4 (Top 16 Distribution - 2013 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2012['MC4'],bins=10,facecolor='black', ec='black', alpha = 0.5)
plt.title('MC4 (Top 16 Distribution - 2012 - Group Stage)', fontweight='bold')

plt.show()

# %%
# PLOT DP3(2012-2019)
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2019['DP3'],bins=10,facecolor='green', ec='black', alpha = 0.6)
plt.style.use('seaborn-white')
plt.title('DP3 (Top 16 Distribution - 2019 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2018['DP3'],bins=10,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP3 (Top 16 Distribution - 2018 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2017['DP3'],bins=10,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP3 (Top 16 Distribution - 2017 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2016['DP3'],bins=10,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP3 (Top 16 Distribution - 2016 - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2015['DP3'],bins=10,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP3(Top 16 Distribution - 2015 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2014['DP3'],bins=10,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP3 (Top 16 Distribution - 2014 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2013['DP3'],bins=10,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP3 (Top 16 Distribution - 2013 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2012['DP3'],bins=10,facecolor='green', ec='black', alpha = 0.6)
plt.title('DP3 (Top 16 Distribution - 2012 - Group Stage)', fontweight='bold')

plt.show()

# %%
# PLOT KB2(2012-2019)
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2019['KB2'],bins=10,facecolor='blue', ec='black', alpha = 0.5)
plt.title('KB2 (Top 16 Distribution - 2019 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2018['KB2'],bins=10,facecolor='blue', ec='black', alpha = 0.5)
plt.title('KB2 (Top 16 Distribution - 2018 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2017['KB2'],bins=10,facecolor='blue', ec='black', alpha = 0.5)
plt.title('KB2 (Top 16 Distribution - 2017 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2016['KB2'],bins=10,facecolor='blue', ec='black', alpha = 0.5)
plt.title('KB2 (Top 16 Distribution - 2016 - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2015['KB2'],bins=10,facecolor='blue', ec='black', alpha = 0.5)
plt.title('KB2 (Top 16 Distribution - 2015 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2014['KB2'],bins=10,facecolor='blue', ec='black', alpha = 0.5)
plt.title('KB2 (Top 16 Distribution - 2014 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2013['KB2'],bins=10,facecolor='blue', ec='black', alpha = 0.5)
plt.title('KB2 (Top 16 Distribution - 2013 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2012['KB2'],bins=10,facecolor='blue', ec='black', alpha = 0.5)
plt.title('KB2 (Top 16 Distribution - 2012 - Group Stage)', fontweight='bold')

plt.show()

# %%
# PLOT GV3(2012-2019)
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2019['GV3'],bins=10,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV3 (Top 16 Distribution - 2019 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2018['GV3'],bins=10,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV3 (Top 16 Distribution - 2018 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2017['GV3'],bins=10,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV3 (Top 16 Distribution - 2017 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2016['GV3'],bins=10,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV3 (Top 16 Distribution - 2016 - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2015['GV3'],bins=10,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV3 (Top 16 Distribution - 2015 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2014['GV3'],bins=10,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV3 (Top 16 Distribution - 2014 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2013['GV3'],bins=10,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV3 (Top 16 Distribution - 2013 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2012['GV3'],bins=10,facecolor='brown', ec='black', alpha = 0.8)
plt.title('GV3 (Top 16 Distribution - 2012 - Group Stage)', fontweight='bold')

plt.show()

# %%
# PLOT VL2(2012-2019)
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2019['VL2'],bins=10,facecolor='cyan', ec='black', alpha = 0.5)
plt.title('VL2 (Top 16 Distribution - 2019 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2018['VL2'],bins=10,facecolor='cyan', ec='black', alpha = 0.5)
plt.title('VL2 (Top 16 Distribution - 2018 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2017['VL2'],bins=10,facecolor='cyan', ec='black', alpha = 0.5)
plt.title('VL2 (Top 16 Distribution - 2017 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2016['VL2'],bins=10,facecolor='cyan', ec='black', alpha = 0.5)
plt.title('VL2 (Top 16 Distribution - 2016 - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2015['VL2'],bins=10,facecolor='cyan', ec='black', alpha = 0.5)
plt.title('VL2 (Top 16 Distribution - 2015 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2014['VL2'],bins=10,facecolor='cyan', ec='black', alpha = 0.5)
plt.title('VL2 (Top 16 Distribution - 2014 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2013['VL2'],bins=10,facecolor='cyan', ec='black', alpha = 0.5)
plt.title('VL2 (Top 16 Distribution - 2013 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2012['VL2'],bins=10,facecolor='cyan', ec='black', alpha = 0.5)
plt.title('VL2 (Top 16 Distribution - 2012 - Group Stage)', fontweight='bold')

plt.show()

# %%
# PLOT RR (2012-2019)
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2019['RR'],facecolor='purple', ec='black', alpha = 0.5)
plt.title('RR (Top 16 Distribution - 2019 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2018['RR'],facecolor='purple', ec='black', alpha = 0.5)
plt.title('RR (Top 16 Distribution - 2018 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2017['RR'],facecolor='purple', ec='black', alpha = 0.5)
plt.title('RR (Top 16 Distribution - 2017 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2016['RR'],facecolor='purple', ec='black', alpha = 0.5)
plt.title('RR (Top 16 Distribution - 2016 - Group Stage)', fontweight='bold')

plt.show()

plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.hist(top16_2015['RR'],facecolor='purple', ec='black', alpha = 0.5)
plt.title('RR (Top 16 Distribution - 2015 - Group Stage)', fontweight='bold')

plt.subplot(2,2,2)
plt.hist(top16_2014['RR'],facecolor='purple', ec='black', alpha = 0.5)
plt.title('RR (Top 16 Distribution - 2014 - Group Stage)', fontweight='bold')

plt.subplot(2,2,3)
plt.hist(top16_2013['RR'],facecolor='purple', ec='black', alpha = 0.5)
plt.title('RR (Top 16 Distribution - 2013 - Group Stage)', fontweight='bold')

plt.subplot(2,2,4)
plt.hist(top16_2012['RR'],facecolor='purple', ec='black', alpha = 0.5)
plt.title('RR (Top 16 Distribution - 2012 - Group Stage)', fontweight='bold')

plt.show()

# %% [markdown]
# #### Commentaires:
# - Même s'il reste des outliers, les chronos se resserent entre les membres qualifiés pour le top 16.
# - On peut distinguer plusieurs types de courses:
# - 1) Les circuits avec des écarts d'environ 5 secondes entre les différents chronos du top 16 (MC1,DP1,GV1,GV2).
# - 2) Les circuits avec des écarts entre 5 et 10 secondes (concernent la majorité des circuits).
# - 3) Les circuits avec les plus gros outliers (BC3,GV3,VL2,RR).
